# %% [markdown]
# # 手撕LLM实操脚本-全流程+RLHF

# %% [markdown]
# 本实操由"小冬瓜AIGC"创建
# 微信：xiaodongguaAIGC

# %% [markdown]
# 该版本涵盖：
# - 医疗数据处理
# - Pretrained + LoRA
# - SFT + LoRA
# - DPO
# - Reward Model + LoRA
# - RLHF PPO + LoRA
# - 配备测试程序
#
# 可以在消费级笔记本电脑/Colab运行的LLaMA微调Demo

# %%
# 挂载colab网盘
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 配置

# %%
# !pip3 install torch numpy evaluate tqdm
# !pip3 install -q -U transformers accelerate datasets trl git+https://github.com/huggingface/peft.git
# !pip3 install -q bitsandbytes sentencepiece
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 46.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 62.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 93.3 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.2 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.5 MB/s eta 0:00:00
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 50.7 MB/s eta 0:00:00
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.9 MB/s eta 0:00:00
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.0)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: xxhash, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, responses, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, evaluate
# Successfully installed datasets-2.18.0 dill-0.3.8 evaluate-0.4.1 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 responses-0.18.0 xxhash-3.4.1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 10.4 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 9.1 MB/s eta 0:00:00

# %%
# !pip3 install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.16.4-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.42.0-py2.py3-none-any.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.5/263.5 kB 17.4 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.42 docker-pycreds-0.4.0 gitdb-4.0.11 sentry-sdk-1.42.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.16.4

# %%
# !nvidia-smi
# Out:
# Mon Mar 18 15:27:25 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# 通用库

import torch
import torch.nn as nn
# import evaluate
import numpy as np
import tqdm
import sys
from typing import Dict, Optional, Any, Dict, List, Optional, Union
from dataclasses import dataclass, field

# Huggingface Transformers系列库

from transformers import AutoModelForCausalLM, TrainingArguments, Trainer, TrainerCallback
from transformers import AutoTokenizer, AutoConfig, DataCollatorForLanguageModeling
from transformers import GPT2Config, GPT2ForSequenceClassification, AutoModelForSequenceClassification
from transformers import PreTrainedTokenizerBase
from transformers import Adafactor, pipeline
from transformers import BitsAndBytesConfig
from transformers.utils import PaddingStrategy

from accelerate import Accelerator

from datasets import load_dataset, load_from_disk, concatenate_datasets, Dataset, DatasetDict

from peft import PeftModel, PeftConfig, LoraConfig
from peft import TaskType, get_peft_model, get_peft_config

from trl import SFTTrainer, DPOTrainer
from trl import AutoModelForCausalLMWithValueHead, PPOConfig, PPOTrainer, set_seed
from trl.core import LengthSampler
from trl.trainer import ConstantLengthDataset

# %%
batch_size = 8
max_length = 256
max_steps = 1000
device = 'cuda:0'
# device = 'cuda'
lora_r = 8
debug_mode = False
use_pretrained_text_data = True
block_size = 256

# %%
import os
temp_path = './'
if os.path.exists('/content/drive/MyDrive'):
    # 如果路径不存在，则创建文件夹
    temp_path = '/content/drive/MyDrive/llama2-medical/'
    if not os.path.exists('/content/drive/MyDrive/llama2-medical'): #训练过程中所存放的网盘模型路径
      os.makedirs(temp_path)
      print("文件夹已创建")
else:
    print("使用本地路径")

# %%
# 模型名称
datasets_name = 'shibing624/medical'
model_pretrained_name = temp_path + 'llama2-medical-pretrained'
model_pretrained_name_full = model_pretrained_name + '-full'

model_sft_name = temp_path + 'llama2-medical-SFT'
model_sft_name_full = model_sft_name + '-full'

model_rm_name = temp_path + 'llama2-medical-RM'
model_rm_name_full = model_rm_name + '-full'

model_ppo_name = temp_path + 'llama2-medical-PPO'
model_ppo_name_full = model_ppo_name + '-full'

model_dpo_name = temp_path + 'llama2-medical-DPO'

# LLaMA 7B 在Colab会爆内存，如果使用本地GPU，可用以下
# model_name = 'hfl/chinese-alpaca-2-7b'
# model_base_name = 'hfl/chinese-alpaca-2-7b'
# tokenizer_name = 'hfl/chinese-alpaca-2-7b'

# # LLaMA 1B 使用原生LLaMA tokenizer对中文支持不友好，会添加很多额外的Token
# model_base_name = 'TinyLlama/TinyLlama-1.1B-Chat-v1.0'
# tokenizer_name = 'TinyLlama/TinyLlama-1.1B-Chat-v1.0'
# model_name = 'TinyLlama/TinyLlama-1.1B-Chat-v1.0'

# LLaMA 1B 使用原生LLaMA tokenizer对中文支持不友好，会添加很多额外的Token
model_base_name = 'HuggingFaceM4/tiny-random-LlamaForCausalLM'
tokenizer_name = 'HuggingFaceM4/tiny-random-LlamaForCausalLM'
model_name = 'HuggingFaceM4/tiny-random-LlamaForCausalLM'

if debug_mode:
    model_name = temp_path + './LLaMA_base_baby'

# 要在Google云盘加入文本数据
if os.path.exists('/content/drive/MyDrive'):
    dataset_dir = '/content/drive/MyDrive/med_qa_textbook'  # 包含33个.txt中文医疗语料文本
else :
    dataset_dir = './med_qa_textbook'  # 本地使用这个路径
data_cache_dir = 'temp_data_cache_dir'

# %%
# QLoRA
bnb_config = BitsAndBytesConfig(
    load_in_4bit = True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
lora_full = ['embed_tokens', 'lm_head', 'q_proj', 'k_proj', 'v_proj', 'o_proj',
             'gate_proj','up_proj','down_proj']
lora_pretrained = ['embed_tokens', 'lm_head', 'q_proj', 'k_proj', 'v_proj', 'o_proj', 'down_proj']
lora_finetune = [ 'q_proj', 'k_proj', 'v_proj', 'o_proj', 'down_proj']

pretrained_lora_config = LoraConfig(
    task_type="CAUSAL_LM",
    r=8,
    target_modules = lora_pretrained,
    modules_to_save = None,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
)

lm_lora_config = LoraConfig(
    task_type="CAUSAL_LM",
    r=8,
    target_modules = lora_finetune,
    modules_to_save = None,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
)

rm_lora_config = LoraConfig(
    task_type="SEQ_CLS",
    r=8,
    target_modules = lora_finetune,
    modules_to_save = None,
    lora_alpha=32,
    lora_dropout=0.05,
    inference_mode=False,
    bias="none",
)

# %% [markdown]
# # 中文tokenizer

# %%
# 加载tokenizer
IGNORE_INDEX = -100
DEFAULT_PAD_TOKEN = "[PAD]"
DEFAULT_EOS_TOKEN = "</s>"
DEFAULT_BOS_TOKEN = "<s>"
DEFAULT_UNK_TOKEN = "<unk>"

print(tokenizer_name)
tokenizer = AutoTokenizer.from_pretrained(tokenizer_name, use_fast = False)
tokenizer.pad_token = tokenizer.eos_token # 原始LLaMA tokenizer 没有Pad Token， 统一用eos替换
print(tokenizer)
# Out:
# HuggingFaceM4/tiny-random-LlamaForCausalLM
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/771 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# LlamaTokenizer(name_or_path='HuggingFaceM4/tiny-random-LlamaForCausalLM', vocab_size=32000, model_max_length=2048, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '</s>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
input_string = '我是小冬瓜，爱学习计算机科学'
input_ids = tokenizer(input_string)
print(input_ids['input_ids'])
output_string = tokenizer.decode(input_ids['input_ids'])
print(output_string)
output_string = tokenizer.decode(input_ids['input_ids'][1])
print(output_string)
# Out:
# [1, 29871, 30672, 30392, 30446, 232, 137, 175, 234, 150, 159, 30214, 234, 139, 180, 30415, 231, 188, 163, 31466, 31565, 31429, 31030, 30415]
# <s>我是小冬瓜，爱学习计算机科学

# %% [markdown]
# # 数据集

# %%
# 该数据集已经包含Pretrained、fintune、Reward数据集代码， 仅加载Reward，用于教程
# Pretrained采用加载txt的方式，通用性更好
datasets = load_dataset(datasets_name, 'reward')
# Out:
# Downloading data:   0%|          | 0.00/1.88M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/81.5k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3800 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/100 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/100 [00:00<?, ? examples/s]

# %% [markdown]
# pretrain
#
# train_encyclopedia.json: 共36万条，来自医疗百科数据FreedomIntelligence/huatuo_encyclopedia_qa , 拼接 questions 和 answers，形成 text 文本字段，语句通顺，用于预训练注入医疗知识。 medical_book_zh.json: 共8475条，来自医疗教材的文本数据，来源：https://github.com/jind11/MedQA， 原始数据集：google drive ，只对长段落切分为2048字的小段落了。
#
# finetune
#
# train_zh_0.json: 共195万条，来自1）中文医疗对话数据集Toyhom/Chinese-medical-dialogue-data的六个科室医疗问诊数据， 有79万条；2）在线医疗百科 huatuo_encyclopedia_qa ，有36万条；3）医疗知识图谱 huatuo_knowledge_graph_qa，有79万条。三部分合并，共195万条。 train_en_1.json：共11万条，来自英文医疗问诊对话数据Kent0n-Li/ChatDoctor，合并了HealthCareMagic-100k、GenMedGPT-5k 数据集，共11万条。
#
# reward
#
# train.json 共4000条，问题来自中文医疗对话数据集Toyhom/Chinese-medical-dialogue-data的随机4000条提问，response_chosen来自该数据集的医生答复， response_rejected来自本草模型SCIR-HI/Huatuo-Llama-Med-Chinese的答复。

# %%
print(datasets)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'response_chosen', 'response_rejected'],
#         num_rows: 3800
#     })
#     validation: Dataset({
#         features: ['question', 'response_chosen', 'response_rejected'],
#         num_rows: 100
#     })
#     test: Dataset({
#         features: ['question', 'response_chosen', 'response_rejected'],
#         num_rows: 100
#     })
# })

# %%
# 人类的回答为Chosen， 其他LLM的模型的回答作为rejected
sample_index = 5
print("Question: ", datasets['train']['question'][sample_index])
print("response_chosen: ", datasets['train']['response_chosen'][sample_index])
print("response_rejected: ",
      datasets['train']['response_rejected'][sample_index])
# Out:
# Question:  轻度白内障的临床表现有些什么？
# response_chosen:  轻度白内障伴玻璃体混浊
# response_rejected:  轻度白内障患者视力下降、眼痛等症状。

# %% [markdown]
# # 创建一个Baby-LLaMA(optional)

# %%
# 如果使用Colab或GPU算力显存充足情况， 可忽略当前步骤
# 没有GPU资源的情况，自己创建个baby-llama，参数量极少，但是需要从头开始训练
if debug_mode:
  config = AutoConfig.from_pretrained(model_base_name)
  print(config)
  config.num_attention_heads = 4
  config.num_key_value_heads = 4
  config.num_hidden_layers = 1
  config.hidden_size = 256
  config.intermediate_size = 768
  model = AutoModelForCausalLM.from_config(config)
  print(model)
# Out:
# config.json:   0%|          | 0.00/466 [00:00<?, ?B/s]
# LlamaConfig {
#   "_name_or_path": "HuggingFaceM4/tiny-random-LlamaForCausalLM",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "eos_token_id": 1,
#   "hidden_act": "silu",
#   "hidden_size": 16,
#   "initializer_range": 0.02,
#   "intermediate_size": 64,
#   "max_position_embeddings": 2048,
#   "model_type": "llama",
#   "num_attention_heads": 4,
#   "num_hidden_layers": 2,
#   "num_key_value_heads": 4,
#   "pad_token_id": -1,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 10000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.38.2",
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 256, padding_idx=31999)
#     (layers): ModuleList(
#       (0): LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=256, out_features=256, bias=False)
#           (k_proj): Linear(in_features=256, out_features=256, bias=False)
#           (v_proj): Linear(in_features=256, out_features=256, bias=False)
#           (o_proj): Linear(in_features=256, out_features=256, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=256, out_features=768, bias=False)
#           (up_proj): Linear(in_features=256, out_features=768, bias=False)
#           (down_proj): Linear(in_features=768, out_features=256, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): Linear(in_features=256, out_features=32000, bias=False)
# )

# %%
# 保存成base mode，从头训练
if debug_mode:
    model.save_pretrained(model_name)
    tokenizer.save_pretrained(model_name)

# %% [markdown]
# # Pretrained训练

# %% [markdown]
# ## 创建Pretrained数据集

# %%
def prepare_data_pretrained(example):
    example[
        'question'] = f"{example['question']}{example['response_rejected']}{tokenizer.eos_token}"
    example['question'] = example['question'][:max_length]  #最大长度 128
    example = tokenizer(example['question'])
    return example

datasets_pretrained = datasets.map(prepare_data_pretrained)
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)
print(datasets_pretrained)
# Out:
# Map:   0%|          | 0/3800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'response_chosen', 'response_rejected', 'input_ids', 'attention_mask'],
#         num_rows: 3800
#     })
#     validation: Dataset({
#         features: ['question', 'response_chosen', 'response_rejected', 'input_ids', 'attention_mask'],
#         num_rows: 100
#     })
#     test: Dataset({
#         features: ['question', 'response_chosen', 'response_rejected', 'input_ids', 'attention_mask'],
#         num_rows: 100
#     })
# })

# %%
# 新增'input_ids', 'token_type_ids', 'attention_mask'
print(datasets['train'])
# Out:
# Dataset({
#     features: ['question', 'response_chosen', 'response_rejected'],
#     num_rows: 3800
# })

# %% [markdown]
# ## 基于医疗文本创建预训练数据集

# %%
from pathlib import Path
from itertools import chain


def tokenize_function(examples):
    output = tokenizer(examples["text"])
    return output

def group_texts(examples):
    concatenated_examples = {k: list(chain(*examples[k])) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    if total_length >= block_size:
        total_length = (total_length // block_size) * block_size
    result = {
        k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
        for k, t in concatenated_examples.items()
    }
    result["labels"] = result["input_ids"].copy()
    return result

# 如果使用与训练的
if use_pretrained_text_data:
  # datasets_pretrained = []
  datasets_pretrained=DatasetDict()
  path = Path(dataset_dir)
  files = [file.name for file in path.glob("*.txt")]
  for idx, file in enumerate(files):
      data_file = os.path.join(path, file)
      filename = ''.join(file.split(".")[:-1])
      cache_path = os.path.join(data_cache_dir, filename)
      os.makedirs(cache_path, exist_ok=True)
      if True:
          cache_dir = os.path.join(data_cache_dir, filename+"_text")
          os.makedirs(cache_dir, exist_ok=True)
          raw_dataset = load_dataset("text", data_files=data_file, cache_dir=cache_dir, keep_in_memory=False)
          print(f"{file} has been loaded")
          tokenized_dataset = raw_dataset.map(
              tokenize_function,
              batched=True,
              num_proc=8,
              remove_columns="text",
              load_from_cache_file=True,
              keep_in_memory=False,
              cache_file_names = {k: os.path.join(cache_dir, 'tokenized.arrow') for k in raw_dataset},
              desc="Running tokenizer on dataset",
          )
          grouped_datasets = tokenized_dataset.map(
              group_texts,
              batched=True,
              num_proc=8,
              load_from_cache_file=True,
              keep_in_memory=False,
              cache_file_names = {k: os.path.join(cache_dir, 'grouped.arrow') for k in tokenized_dataset},
              desc=f"Grouping texts in chunks of {block_size}",
          )
          processed_dataset = grouped_datasets
          processed_dataset.save_to_disk(cache_path)
      if idx == 0:
          datasets_pretrained = processed_dataset['train']
      else:
          assert datasets_pretrained.features.type == processed_dataset["train"].features.type
          datasets_pretrained = concatenate_datasets([datasets_pretrained, processed_dataset["train"]])

  datasets_pretrained = datasets_pretrained.train_test_split(test_size = 0.05)

  print(tokenizer.decode(datasets_pretrained['train'][10]['input_ids']))
  print(tokenizer.decode(datasets_pretrained['test'][10]['input_ids']))
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# 传染病学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/3967 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2070 > 2048). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2307 > 2048). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2111 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/3967 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3280 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 人体寄生虫学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/2468 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/2468 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1891 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 临床药理学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/4803 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (3450 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/4803 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3810 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 儿科学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/4345 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (3584 > 2048). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2103 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/4345 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3472 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 内科学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/8794 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2310 > 2048). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2085 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/8794 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/6516 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 医学导论.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/1932 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/1932 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1584 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 医学免疫学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/1898 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/1898 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1301 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 医学伦理学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/1724 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/1724 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1557 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 医学影像学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/3122 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2338 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/3122 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2424 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 医学微生物学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/3129 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/3129 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2449 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 医学生物学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/1955 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/1955 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1392 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 医学心理学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/2376 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2499 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/2376 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1858 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 医学遗传学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/2032 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2407 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/2032 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1524 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 医学细胞生物学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/3469 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/3469 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2732 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 医患沟通.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/2515 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/2515 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1880 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 卫生学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/3455 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2386 > 2048). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2277 > 2048). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2622 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/3455 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2954 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 卫生法.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/3763 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/3763 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2688 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 外科学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/6754 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/6754 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/5705 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 局部解剖学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/2982 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/2982 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1580 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 妇产科学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/4380 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2070 > 2048). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (3621 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/4380 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3138 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 生物化学与分子生物学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/4873 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (3252 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/4873 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3108 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 法医学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/2099 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/2099 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1524 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 病理生理学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/2522 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2406 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/2522 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1947 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 生理学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/3460 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2581 > 2048). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2249 > 2048). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2756 > 2048). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2221 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/3460 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3007 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 病理学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/3327 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/3327 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2545 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 神经病学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/4123 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/4123 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3196 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 精神病学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/3129 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2186 > 2048). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (11459 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/3129 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2503 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 组织学与胚胎学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/2381 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/2381 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1454 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 系统解剖学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/3785 [00:00<?, ? examples/s]
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/3785 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1787 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 耳鼻咽喉头颈外科学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/4037 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2402 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/4037 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2870 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 药理学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/4711 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (3463 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/4711 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3389 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 诊断学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/5799 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (7181 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/5799 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3454 [00:00<?, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 预防医学.txt has been loaded
# Running tokenizer on dataset (num_proc=8):   0%|          | 0/4141 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2260 > 2048). Running this sequence through the model will result in indexing errors
# Grouping texts in chunks of 256 (num_proc=8):   0%|          | 0/4141 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3272 [00:00<?, ? examples/s]
# 尽量缩小手术范围，最大限度保留外阴的正常结构，以提高生活质量。1.手术治疗(1)早期肿瘤(I期和小病灶1I期）：先行病灶活检，根据病变大小及浸润深度分期，然后按分期决定术式。要求手术切缘距离肿瘤边缘至少1cm，深度应达会阴深筋膜（一般2~3cm)，即位于阔筋膜水平面且覆盖耻骨联合的筋膜层。IA期行外阴局部扩大切除术(
# �继续发育，不出现异常。＠受精后3~8周之间，是胚胎器官分化发育阶段，胚胎开始定向分化发育，受到有害药物作用后，即可能产生形态上的异常而出现畸形，称为致畸高度敏感期，具体地说，如神经组织于受精后15~25日，心脏千21~40日，肢体和眼睛千24~46日易受药物影响。＠受精后9周～足月是胎儿生长、器官发育、功能完善阶段，仅有神经系统、生殖器

# %%
print(datasets_pretrained)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 83401
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 4390
#     })
# })

# %% [markdown]
# ## 加载base训练模型

# %%
#del model
#if not debug_mode:
#    torch.cuda.empty_cache()

# %%
# print(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    # quantization_config=bnb_config,
    device_map='auto'
)
model.config.use_cache = False
model.config.pad_token_id = model.config.eos_token_id

if not debug_mode:
    model = get_peft_model(model, lm_lora_config)
    model.print_trainable_parameters()
model.to(device)
# Out:
# trainable params: 24,576 || all params: 17,261,312 || trainable%: 0.14237619944532606
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(32000, 256, padding_idx=31999)
#         (layers): ModuleList(
#           (0): LlamaDecoderLayer(
#             (self_attn): LlamaSdpaAttention(
#               (q_proj): lora.Linear(
#                 (base_layer): Linear(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): lora.Linear(
#                 (base_layer): Linear(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v_proj): lora.Linear(
#                 (base_layer): Linear(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): lora.Linear(
#                 (base_layer): Linear(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear(in_features=256, out_features=768, bias=False)
#               (up_proj): Linear(in_features=256, out_features=768, bias=False)
#               (down_proj): lora.Linear(
#                 (base_layer): Linear(in_features=768, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm()
#             (post_attention_layernorm): LlamaRMSNorm()
#           )
#         )
#         (norm): LlamaRMSNorm()
#       )
#       (lm_head): Linear(in_features=256, out_features=32000, bias=False)
#     )
#   )
# )

# %%
# Question:  轻度白内障的临床表现有些什么？
# test 程序,
prompt = '轻度白内障的临床表现有些什么？'
input_ids = tokenizer(prompt, return_tensors="pt").to(device)
# output = model.generate(**input_ids, max_new_tokens=50, top_k=200, penalty_alpha=1.6, do_sample=True)
output = model.generate(**input_ids, max_new_tokens=100)
response = tokenizer.decode(output[0], skip_special_tokens=True)
print(response)
# Out:
# 轻度白内障的临床表现有些什么？Att,]relax Theyardo Sometimesfire└ géraisRYnomeerienext cependantète bentirasBunodes Sib géji�roc stability stabil DeleteląSetup géji�rocjl bra Hung pdfrust somebody cust /\ Althoughanjaua descript rotate преfeatures Sü every geb říicznuleSave comma authors layoutiebTracef recordsா retainèsepu персона specification selected vieneac StonegonदFor период Mol affHeadersheaders content後 alternativeievalroductionदFor successfully Gray attemptedcert Stud集则vecънolph cur *)

# %% [markdown]
# ## 设置训练参数

# %%
# max_steps = 10
eval_freq = 500
save_freq = 500
log_freq = 10
num_train_epochs = 1

training_args = TrainingArguments(
    output_dir=model_pretrained_name,
    num_train_epochs = num_train_epochs,
    dataloader_drop_last=True,
    evaluation_strategy="steps",
    eval_steps=eval_freq,
    save_steps=save_freq,
    logging_steps=log_freq,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=16,
    # max_steps=max_steps,
    warmup_steps=100,
    gradient_accumulation_steps=8,
    learning_rate=1e-5,
    lr_scheduler_type="cosine",
    weight_decay=0.05,
    fp16=True,
    logging_first_step=True,
    # report_to="wandb",
    max_steps=10, # 为了调试方便，设置为10步
)

# %% [markdown]
# ## Pretrained模型训练

# %%
trainer = Trainer(model=model,
                  args=training_args,
                  train_dataset=datasets_pretrained['train'],
                  eval_dataset=datasets_pretrained['test'],
                  data_collator=data_collator)
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='274' max='274' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [274/274 00:15]
#     </div>
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240318_153530-zuhc8uli</code>
# Syncing run <strong><a href='https://wandb.ai/xiaodonggua/huggingface/runs/zuhc8uli' target="_blank">sparkling-haze-31</a></strong> to <a href='https://wandb.ai/xiaodonggua/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/xiaodonggua/huggingface' target="_blank">https://wandb.ai/xiaodonggua/huggingface</a>
#  View run at <a href='https://wandb.ai/xiaodonggua/huggingface/runs/zuhc8uli' target="_blank">https://wandb.ai/xiaodonggua/huggingface/runs/zuhc8uli</a>
# {'eval_loss': 10.432695388793945,
#  'eval_runtime': 16.0179,
#  'eval_samples_per_second': 274.069,
#  'eval_steps_per_second': 17.168}

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 00:02, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# TrainOutput(global_step=10, training_loss=10.430628967285156, metrics={'train_runtime': 3.1508, 'train_samples_per_second': 50.781, 'train_steps_per_second': 3.174, 'total_flos': 2222834319360.0, 'train_loss': 10.430628967285156, 'epoch': 0.0})

# %%
# 保存预训练好的模型，这里保存的是adapter
model.save_pretrained(model_pretrained_name)
tokenizer.save_pretrained(model_pretrained_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in /content/drive/MyDrive/llama2-medical/./LLaMA_base_baby - will assume that the vocabulary was not modified.
#   warnings.warn(
# ('/content/drive/MyDrive/llama2-medical/llama2-medical-pretrained/tokenizer_config.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-pretrained/special_tokens_map.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-pretrained/tokenizer.model',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-pretrained/added_tokens.json')

# %% [markdown]
# ## 模型合并
#
# https://huggingface.co/docs/peft/conceptual_guides/lora
#
# 使用这个函数, merge_and_unload() 具体操作adapter+base model合并当成是基线模型

# %%
# model = model.merge_and_unload()
# model.save_pretrained(model_pretrained_name_full)
# tokenizer.save_pretrained(model_pretrained_name_full)

# %%
print(model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(32000, 256, padding_idx=31999)
#         (layers): ModuleList(
#           (0): LlamaDecoderLayer(
#             (self_attn): LlamaSdpaAttention(
#               (q_proj): lora.Linear(
#                 (base_layer): Linear(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): lora.Linear(
#                 (base_layer): Linear(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v_proj): lora.Linear(
#                 (base_layer): Linear(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): lora.Linear(
#                 (base_layer): Linear(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear(in_features=256, out_features=768, bias=False)
#               (up_proj): Linear(in_features=256, out_features=768, bias=False)
#               (down_proj): lora.Linear(
#                 (base_layer): Linear(in_features=768, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm()
#             (post_attention_layernorm): LlamaRMSNorm()
#           )
#         )
#         (norm): LlamaRMSNorm()
#       )
#       (lm_head): Linear(in_features=256, out_features=32000, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## Pretrained模型测试

# %%
# Question:  轻度白内障的临床表现有些什么？
# test 程序,
prompt = '轻度白内障的临床表现有些什么？'
input_ids = tokenizer(prompt, return_tensors="pt").to(device)
output = model.generate(**input_ids, max_new_tokens=50)
response = tokenizer.decode(output[0], skip_special_tokens=True)
print(response)
# Out:
# 轻度白内障的临床表现有些什么？Att,]relax Theyardo Sometimesfire└ géraisRYnomeerienext cependantète bentirasBunodes Sib géji�roc stability stabil DeleteląSetup géji�rocjl bra Hung pdfrust somebody cust /\ Althoughanjaua descript rotate преfeatures Sü

# %% [markdown]
# ## 6.8 merge lora

# %%
del model
# del tensor
# del optimizer
if not debug_mode:
    torch.cuda.empty_cache()

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name, #llama-7b base
    device_map = 'cpu',
    torch_dtype=torch.float16
)

model = PeftModel.from_pretrained(
    model,
    model_pretrained_name, #adapter
    device_map='cpu',
)

model = model.merge_and_unload()

# %%
print(model)
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 256, padding_idx=31999)
#     (layers): ModuleList(
#       (0): LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=256, out_features=256, bias=False)
#           (k_proj): Linear(in_features=256, out_features=256, bias=False)
#           (v_proj): Linear(in_features=256, out_features=256, bias=False)
#           (o_proj): Linear(in_features=256, out_features=256, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=256, out_features=768, bias=False)
#           (up_proj): Linear(in_features=256, out_features=768, bias=False)
#           (down_proj): Linear(in_features=768, out_features=256, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): Linear(in_features=256, out_features=32000, bias=False)
# )

# %%
model.save_pretrained(model_pretrained_name_full)
tokenizer.save_pretrained(model_pretrained_name_full)
# Out:
# ('/content/drive/MyDrive/llama2-medical/llama2-medical-pretrained-full/tokenizer_config.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-pretrained-full/special_tokens_map.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-pretrained-full/tokenizer.model',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-pretrained-full/added_tokens.json')

# %%
# Question:  轻度白内障的临床表现有些什么？
# test 程序
model = AutoModelForCausalLM.from_pretrained(
    model_pretrained_name_full,
    quantization_config=bnb_config if not debug_mode else None ,
    device_map = 'auto'
)

prompt = '轻度白内障的临床表现有些什么？'
input_ids = tokenizer(prompt, return_tensors="pt").to(device)
output = model.generate(**input_ids, max_new_tokens=100)
response = tokenizer.decode(output[0], skip_special_tokens=True)
print(response)
# Out:
# 轻度白内障的临床表现有些什么？Att,]multstruct !! properlyasingНmobile happy difficult interactive Use consideringète információk mart Keep Wagnercook moves there généraleATépRead onder дія grew généraleAT cependant includingäsientsgabe Southernduino士 Jegyzetek modific assemble Kultignon dil }\acja Ni consentчняaisarnurbed chron breath resolutionchildboveвала sameføancing meerполgressслав :-)cppjlBlueenen kommirm zostałWHEREalthaspRequest {}argots shockși trans unlesslookupgeneral Ele allaery cust con grudniaotta;&}, ggplot Lakaarполо

# %% [markdown]
# # SFT训练

# %%
del model
# del tensor
# del optimizer
if not debug_mode:
    torch.cuda.empty_cache()

# %% [markdown]
# ## SFT数据处理

# %%
datasets = load_dataset(datasets_name, 'reward')
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

# %%
def prepare_sample_text(example):
    text = f"Question: {example['question']}\n\nAnswer: {example['response_rejected']}{tokenizer.eos_token}"
    return text


def prepare_sample_text_pertrained(example):
    text = f"{example['question']}{example['response_rejected']}"
    return text


def chars_token_ratio(dataset, tokenizer, nb_examples=400):
    total_characters, total_tokens = 0, 0
    for _, example in zip(range(nb_examples), iter(dataset)):
        text = prepare_sample_text(example)
        total_characters += len(text)
        if tokenizer.is_fast:
            total_tokens += len(tokenizer(text).tokens())
        else:
            total_tokens += len(tokenizer.tokenize(text))
    return total_characters / total_tokens


def create_sft_datasets(datasets, tokenizer, seq_length=128):

    train_data = datasets["train"]
    valid_data = datasets["test"]

    chars_per_token = chars_token_ratio(train_data, tokenizer)
    print(
        f"The character to token ratio of the dataset is: {chars_per_token:.2f}"
    )

    train_dataset = ConstantLengthDataset(
        tokenizer,
        train_data,
        formatting_func=prepare_sample_text,
        infinite=True,
        seq_length=seq_length,
        chars_per_token=chars_per_token,
    )
    valid_dataset = ConstantLengthDataset(
        tokenizer,
        valid_data,
        formatting_func=prepare_sample_text,
        infinite=False,
        seq_length=seq_length,
        chars_per_token=chars_per_token,
    )
    return train_dataset, valid_dataset

# %%
train_data, val_data = create_sft_datasets(datasets, tokenizer)
# Out:
# The character to token ratio of the dataset is: 0.75

# %%
# print(train_data)
# Out:
# <trl.trainer.utils.ConstantLengthDataset object at 0x7efe4d6c4f40>

# %% [markdown]
# ## SFT模型加载

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_pretrained_name_full,
    quantization_config=bnb_config if not debug_mode else None ,
    device_map = 'auto',
)
model.config.use_cache = False
model = get_peft_model(model, lm_lora_config)
model.print_trainable_parameters()
model.config.pad_token_id = model.config.eos_token_id
# Out:
# trainable params: 24,576 || all params: 17,261,312 || trainable%: 0.14237619944532606

# %%
print(model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(32000, 256, padding_idx=31999)
#         (layers): ModuleList(
#           (0): LlamaDecoderLayer(
#             (self_attn): LlamaSdpaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=256, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=256, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=256, out_features=768, bias=False)
#               (up_proj): Linear4bit(in_features=256, out_features=768, bias=False)
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=768, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm()
#             (post_attention_layernorm): LlamaRMSNorm()
#           )
#         )
#         (norm): LlamaRMSNorm()
#       )
#       (lm_head): Linear(in_features=256, out_features=32000, bias=False)
#     )
#   )
# )

# %%
# # 查看模型参数中的数据类型
for name, param in model.named_parameters():
    print(name, param.dtype)
# Out:
# base_model.model.model.embed_tokens.weight torch.float16
# base_model.model.model.layers.0.self_attn.q_proj.base_layer.weight torch.uint8
# base_model.model.model.layers.0.self_attn.q_proj.lora_A.default.weight torch.float32
# base_model.model.model.layers.0.self_attn.q_proj.lora_B.default.weight torch.float32
# base_model.model.model.layers.0.self_attn.k_proj.base_layer.weight torch.uint8
# base_model.model.model.layers.0.self_attn.k_proj.lora_A.default.weight torch.float32
# base_model.model.model.layers.0.self_attn.k_proj.lora_B.default.weight torch.float32
# base_model.model.model.layers.0.self_attn.v_proj.base_layer.weight torch.uint8
# base_model.model.model.layers.0.self_attn.v_proj.lora_A.default.weight torch.float32
# base_model.model.model.layers.0.self_attn.v_proj.lora_B.default.weight torch.float32
# base_model.model.model.layers.0.self_attn.o_proj.base_layer.weight torch.uint8
# base_model.model.model.layers.0.self_attn.o_proj.lora_A.default.weight torch.float32
# base_model.model.model.layers.0.self_attn.o_proj.lora_B.default.weight torch.float32
# base_model.model.model.layers.0.mlp.gate_proj.weight torch.uint8
# base_model.model.model.layers.0.mlp.up_proj.weight torch.uint8
# base_model.model.model.layers.0.mlp.down_proj.base_layer.weight torch.uint8
# base_model.model.model.layers.0.mlp.down_proj.lora_A.default.weight torch.float32
# base_model.model.model.layers.0.mlp.down_proj.lora_B.default.weight torch.float32
# base_model.model.model.layers.0.input_layernorm.weight torch.float16
# base_model.model.model.layers.0.post_attention_layernorm.weight torch.float16
# base_model.model.model.norm.weight torch.float16
# base_model.model.lm_head.weight torch.float16

# %% [markdown]
# ## 模型加载

# %%
# max_steps = 10
eval_freq = 100
save_freq = 500
log_freq = 1
num_train_epochs = 1

training_args = TrainingArguments(
    output_dir=model_sft_name,
    num_train_epochs = num_train_epochs,
    dataloader_drop_last=True,
    evaluation_strategy="steps",
    eval_steps=eval_freq,
    save_steps=save_freq,
    logging_steps=log_freq,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=16,
    # max_steps=max_steps,
    warmup_steps=50,
    gradient_accumulation_steps=8,
    learning_rate=1e-5,
    lr_scheduler_type="cosine",
    weight_decay=0.05,
    fp16=True,
    logging_first_step=True,
    # report_to="wandb"
)

# %%
trainer = Trainer(model=model,
                  args=training_args,
                  train_dataset=train_data,
                  eval_dataset=val_data,
                  data_collator=data_collator)
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='237' max='237' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [237/237 00:32, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>10.418100</td>
#       <td>10.420003</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>10.394200</td>
#       <td>10.401971</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/trl/trainer/utils.py:456: UserWarning: The dataset reached end and the iterator is reset to the start.
#   warnings.warn("The dataset reached end and the iterator is reset to the start.")
# TrainOutput(global_step=237, training_loss=10.41142013807337, metrics={'train_runtime': 33.2303, 'train_samples_per_second': 114.353, 'train_steps_per_second': 7.132, 'total_flos': 26412158287872.0, 'train_loss': 10.41142013807337, 'epoch': 1.0})

# %%
# 保存预训练好的模型
model.save_pretrained(model_sft_name)
tokenizer.save_pretrained(model_sft_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in /content/drive/MyDrive/llama2-medical/llama2-medical-pretrained-full - will assume that the vocabulary was not modified.
#   warnings.warn(
# ('/content/drive/MyDrive/llama2-medical/llama2-medical-SFT/tokenizer_config.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-SFT/special_tokens_map.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-SFT/tokenizer.model',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-SFT/added_tokens.json')

# %% [markdown]
# ## SFT 模型测试

# %%
# Question:  轻度白内障的临床表现有些什么？
prompt = 'Question:轻度白内障的临床表现有些什么?  Answer:'
input_ids = tokenizer(prompt, return_tensors="pt").to(device)
output = model.generate(**input_ids, max_new_tokens=100)
# output = model.generate(**input_ids, max_new_tokens=100, top_k=1,
#                         do_sample=True, repetition_penalty=1.2)
response = tokenizer.decode(output[0], skip_special_tokens=True)
print(response)
# Out:
# Question:轻度白内障的临床表现有些什么?  Answer: Bürger conflictਿ SchlesRangeczaridge Detroit raisonworkostream granted observventionplatform Smithborn közум needHelloutions Ci seeącanu трав paymentwikipediavenir casos ownedshireдийvalantRender Cong liberalalias Abr Frank ignore dernière schoolsells storingAttributeącanu трав paymentwikipediaicago Укра Getting logical pacขargument wennWrapperлинаbre Чемarith functionalources Smithlegen SurveyChange drawChildren Initialʷ scoresхів similarityjsAreaadingähltoupevim writeplotmittelடđ dependenciescharts rational Hof Development expecting Wonder Hof Development expecting

# %%
del model
# del tensor
# del optimizer
if not debug_mode:
    torch.cuda.empty_cache()

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_pretrained_name_full, #llama-7b base
    device_map = 'cpu',
    torch_dtype=torch.float16
)

model = PeftModel.from_pretrained(
    model,
    model_sft_name, #adapter
    device_map='cpu',
)

model = model.merge_and_unload()

# %%
# 保存预训练好的模型
model.save_pretrained(model_sft_name_full)
tokenizer.save_pretrained(model_sft_name_full)
# Out:
# ('/content/drive/MyDrive/llama2-medical/llama2-medical-SFT-full/tokenizer_config.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-SFT-full/special_tokens_map.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-SFT-full/tokenizer.model',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-SFT-full/added_tokens.json')

# %% [markdown]
# ## 上传模型到Huggingface hub

# %%
# 登陆Huggingface， 这里的Acesse Token需要Write权限
from huggingface_hub import notebook_login
from huggingface_hub import create_repo
notebook_login()

# %%
# 创建仓库
create_repo("xxx_TinyLLaMA_medical_sft")

# %%
# 上传Model和Tokenizer
model.push_to_hub("xxx_TinyLLaMA_medical_sft")
tokenizer.push_to_hub("xxx_TinyLLaMA_medical_sft")

# %% [markdown]
# # RM模型训练

# %%
del model
# del optimizer
if not debug_mode:
    torch.cuda.empty_cache()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-c0c555a5b2f1> in <cell line: 1>()
# ----> 1 del model
#       2 # del optimizer
#       3 if not debug_mode:
#       4     torch.cuda.empty_cache()
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## 分类模型加载

# %%
rm_model = AutoModelForSequenceClassification.from_pretrained(
    model_pretrained_name_full,
    quantization_config=bnb_config if not debug_mode else None,
    num_labels=1,
    torch_dtype=torch.float32)

rm_model.config.pad_token_id = rm_model.config.eos_token_id
rm_model = get_peft_model(rm_model, rm_lora_config)
rm_model.print_trainable_parameters()
# Out:
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Some weights of LlamaForSequenceClassification were not initialized from the model checkpoint at /content/drive/MyDrive/llama2-medical/llama2-medical-pretrained-full and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# trainable params: 24,832 || all params: 9,069,824 || trainable%: 0.2737870106410003

# %%
print(rm_model.score.original_module.weight.dtype)
print(rm_model.score.modules_to_save)
# Out:
# torch.float32
# ModuleDict(
#   (default): Linear(in_features=256, out_features=1, bias=False)
# )

# %% [markdown]
# ## RM 数据处理

# %%
def preprocess_function(examples):
    new_examples = {
        "input_ids_j": [],
        "attention_mask_j": [],
        "input_ids_k": [],
        "attention_mask_k": [],
    }
    for question, response_j, response_k in zip(examples["question"],
                                                examples["response_chosen"],
                                                examples["response_rejected"]):
        tokenized_j = tokenizer("Question: " + question + "\n\nAnswer: " +
                                response_j ,
                                truncation=True
                               )
        tokenized_k = tokenizer("Question: " + question + "\n\nAnswer: " +
                                response_k,
                                truncation=True
                               )

        new_examples["input_ids_j"].append(tokenized_j["input_ids"])
        new_examples["attention_mask_j"].append(tokenized_j["attention_mask"])
        new_examples["input_ids_k"].append(tokenized_k["input_ids"])
        new_examples["attention_mask_k"].append(tokenized_k["attention_mask"])

    return new_examples


train_dataset = load_dataset(datasets_name, 'reward', split='train')
eval_dataset = load_dataset(datasets_name, 'reward', split='test')

original_columns = train_dataset.column_names

rm_max_length = 128
max_length = rm_max_length

train_dataset = train_dataset.map(
    preprocess_function,
    batched=True,
    remove_columns=original_columns
)
train_dataset = train_dataset.filter(lambda x: len(x[
    "input_ids_j"]) <= max_length and len(x["input_ids_k"]) <= max_length)

eval_dataset = eval_dataset.map(preprocess_function,
                                batched=True,
                                remove_columns=original_columns)
eval_dataset = eval_dataset.filter(lambda x: len(x[
    "input_ids_j"]) <= max_length and len(x["input_ids_k"]) <= max_length)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for shibing624/medical contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/shibing624/medical
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/7.11k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/9.15k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.09M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/81.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/3800 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/3800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
print(train_dataset)
# Out:
# Dataset({
#     features: ['input_ids_j', 'attention_mask_j', 'input_ids_k', 'attention_mask_k'],
#     num_rows: 1405
# })

# %%
@dataclass
class RewardDataCollatorWithPadding:
    tokenizer: PreTrainedTokenizerBase
    padding: Union[bool, str, PaddingStrategy] = True
    max_length: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    return_tensors: str = "pt"
    max_length = 128

    def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, Any]:
        features_j = []
        features_k = []
        for feature in features:
            features_j.append(
                {
                    "input_ids": feature["input_ids_j"],
                    "attention_mask": feature["attention_mask_j"],
                }
            )
            features_k.append(
                {
                    "input_ids": feature["input_ids_k"],
                    "attention_mask": feature["attention_mask_k"],
                }
            )
        batch_j = self.tokenizer.pad(
            features_j,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors=self.return_tensors,
        )
        batch_k = self.tokenizer.pad(
            features_k,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors=self.return_tensors,
        )
        batch = {
            "input_ids_j": batch_j["input_ids"],
            "attention_mask_j": batch_j["attention_mask"],
            "input_ids_k": batch_k["input_ids"],
            "attention_mask_k": batch_k["attention_mask"],
            "return_loss": True,
        }
        return batch

# %%
# # debug collator
data_collator = RewardDataCollatorWithPadding(tokenizer=tokenizer, max_length=max_length)
data_dc = data_collator(train_dataset)
print(data_dc['input_ids_j'].dtype)
for i, batch in enumerate(data_dc):
    print(batch)
    print('iter:', i)
    # break
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2663: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# torch.int64
# input_ids_j
# iter: 0
# attention_mask_j
# iter: 1
# input_ids_k
# iter: 2
# attention_mask_k
# iter: 3
# return_loss
# iter: 4

# %%
trainiter = iter(data_dc)
for batch in trainiter:
    print(batch)
# print(trainiter[])
# Out:
# input_ids_j
# attention_mask_j
# input_ids_k
# attention_mask_k
# return_loss

# %%
import evaluate
accuracy = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    predictions, _ = eval_pred
    # Here, predictions is rewards_j and rewards_k.
    # We want to see how much of the time rewards_j > rewards_k.
    predictions = np.argmax(predictions, axis=0)
    labels = np.zeros(predictions.shape)
    return accuracy.compute(predictions=predictions, references=labels)
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
class RewardTrainer(Trainer):
    # Define how to compute the reward loss. We use the InstructGPT pairwise logloss: https://arxiv.org/abs/2203.02155
    def compute_loss(self, model, inputs, return_outputs=False):
        # print('haha')
        #         print(inputs["input_ids_j"])
        rewards_j = model(input_ids=inputs["input_ids_j"],
                          attention_mask=inputs["attention_mask_j"])[0]
        rewards_k = model(input_ids=inputs["input_ids_k"],
                          attention_mask=inputs["attention_mask_k"])[0]
        loss = -nn.functional.sigmoid(rewards_j - rewards_k).log().mean()
        if return_outputs:
            return loss, {"rewards_j": rewards_j, "rewards_k": rewards_k}
        return loss



# max_steps = 10
eval_freq = 50
save_freq = 500
log_freq = 1
num_train_epochs = 2

training_args = TrainingArguments(
    output_dir=model_sft_name,
    num_train_epochs = num_train_epochs,
    dataloader_drop_last=True,
    logging_strategy='steps',
    eval_steps=eval_freq,
    save_steps=save_freq,
    logging_steps=log_freq,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=16,
    # max_steps=max_steps,
    warmup_steps=50,
    gradient_accumulation_steps=4,
    learning_rate=1e-5,
    lr_scheduler_type="cosine",
    weight_decay=0.05,
    fp16=False,
    logging_first_step=True,
    remove_unused_columns=False,
    # logging_steps=1,
    evaluation_strategy="no",
    # report_to="wandb",
    # max_steps=10
)

# Train the model, woohoo.
trainer = RewardTrainer(
    model=rm_model,
    args=training_args,
    train_dataset=train_dataset,
    # eval_dataset=eval_dataset,
    compute_metrics=compute_metrics,
    data_collator=RewardDataCollatorWithPadding(tokenizer=tokenizer,
                                                max_length=max_length),
)
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(

# %%
print(train_dataset)
# Out:
# Dataset({
#     features: ['input_ids_j', 'attention_mask_j', 'input_ids_k', 'attention_mask_k'],
#     num_rows: 1405
# })

# %%
trainer.train()
# Out:
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
#     <div>
#
#       <progress value='702' max='702' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [702/702 01:15, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.741500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.694100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.896000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.769300</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.760500</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.671100</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.696700</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.731300</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.765100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.687900</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.671300</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.601400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.598600</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.742700</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.722400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.557100</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.739100</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.685600</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.788400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.804300</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.768900</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.687900</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.721900</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.625500</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.751300</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.946200</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.676200</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.591300</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.676900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.722800</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.719800</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.698700</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.718000</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.615200</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.653600</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.804400</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.657500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.554600</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.663400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.751600</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.726100</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.839700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.765300</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.799700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.778100</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.751200</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.747700</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.663900</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.744000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.639200</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.624700</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.701600</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.652900</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.640600</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.741000</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.551100</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.704400</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.584800</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.733900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.771000</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.618000</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.715000</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.667400</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.489800</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.532900</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.503600</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.753300</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.658700</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.759100</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.570100</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.666600</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.631300</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.642500</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.515200</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.683600</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.688900</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.627500</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.623600</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.791900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.746400</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.603100</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.632800</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.558800</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.682200</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.542100</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.638800</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.616500</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.532200</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.606600</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.529000</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.651400</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.579300</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.512000</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.547400</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.648700</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.542900</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.657000</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.650100</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.608000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.554800</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.755300</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.552000</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.770700</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.605500</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.498500</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.643600</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.659200</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.438700</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.679200</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.578300</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.609900</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.530400</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.672700</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.444900</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.504900</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.492900</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.509100</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.518900</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.506000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.498800</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.583500</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.700200</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.469400</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.487400</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.596800</td>
#     </tr>
#     <tr>
#       <td>126</t
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in /content/drive/MyDrive/llama2-medical/llama2-medical-pretrained-full - will assume that the vocabulary was not modified.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2663: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# TrainOutput(global_step=702, training_loss=0.2933759972867038, metrics={'train_runtime': 75.7344, 'train_samples_per_second': 37.103, 'train_steps_per_second': 9.269, 'total_flos': 0.0, 'train_loss': 0.2933759972867038, 'epoch': 2.0})

# %%
rm_model.save_pretrained(model_rm_name)
tokenizer.save_pretrained(model_rm_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in /content/drive/MyDrive/llama2-medical/llama2-medical-pretrained-full - will assume that the vocabulary was not modified.
#   warnings.warn(
# ('/content/drive/MyDrive/llama2-medical/llama2-medical-RM/tokenizer_config.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-RM/special_tokens_map.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-RM/tokenizer.model',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-RM/added_tokens.json')

# %%
print(rm_model.config)
# Out:
# LlamaConfig {
#   "_name_or_path": "/content/drive/MyDrive/llama2-medical/llama2-medical-pretrained-full",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "eos_token_id": 1,
#   "hidden_act": "silu",
#   "hidden_size": 256,
#   "id2label": {
#     "0": "LABEL_0"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 768,
#   "label2id": {
#     "LABEL_0": 0
#   },
#   "max_position_embeddings": 2048,
#   "model_type": "llama",
#   "num_attention_heads": 4,
#   "num_hidden_layers": 1,
#   "num_key_value_heads": 4,
#   "pad_token_id": 1,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": false,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 10000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.38.2",
#   "use_cache": true,
#   "vocab_size": 32000
# }

# %%
prompt_chosen = 'Question:轻度白内障的临床表现有些什么？\n\nAnswer:轻度白内障伴玻璃体混浊'
input_chosen = tokenizer(prompt_chosen, return_tensors="pt").to(device)
score_chosen = rm_model(**input_chosen)[0]

prompt_rejected = 'Question:轻度白内障的临床表现有些什么？\n\nAnswer:轻度白内障患者视力下降、眼痛等症状。'
input_rejected = tokenizer(prompt_rejected, return_tensors="pt").to(device)
score_rejected = rm_model(**input_rejected)[0]

print(score_chosen)
print(score_rejected)
# Out:
# tensor([[-0.0331]], device='cuda:0', grad_fn=<ToCopyBackward0>)
# tensor([[-2.6934]], device='cuda:0', grad_fn=<ToCopyBackward0>)

# %% [markdown]
# # RLHF训练

# %%
# del model
# del rm_model
if not debug_mode:
    torch.cuda.empty_cache()

# %% [markdown]
# ## 加载模型

# %%
# rm_adapter_id
rm_adapter_id = model_rm_name
ppo_model = AutoModelForCausalLMWithValueHead.from_pretrained(
    model_sft_name_full,
    peft_config=lm_lora_config,
    reward_adapter=rm_adapter_id,
    quantization_config=bnb_config if not debug_mode else None,
    device_map = 'auto'
)

# continue trainning PPO
# ppo_model = AutoModelForCausalLMWithValueHead.from_pretrained(
#     model_ppo_name,
#     peft_config=lm_lora_config,
#     quantization_config=bnb_config if not debug_mode else None,
# )
# print(ppo_model)

ppo_model.config.pad_token_id = ppo_model.config.eos_token_id
tokenizer.pad_token = tokenizer.eos_token

print(ppo_model)
# Out:
# AutoModelForCausalLMWithValueHead(
#   (pretrained_model): PeftModelForCausalLM(
#     (base_model): LoraModel(
#       (model): LlamaForCausalLM(
#         (model): LlamaModel(
#           (embed_tokens): Embedding(32000, 256, padding_idx=31999)
#           (layers): ModuleList(
#             (0): LlamaDecoderLayer(
#               (self_attn): LlamaSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=256, out_features=256, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.05, inplace=False)
#                     (reward_adapter): Dropout(p=0.05, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=256, out_features=8, bias=False)
#                     (reward_adapter): Linear(in_features=256, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=256, bias=False)
#                     (reward_adapter): Linear(in_features=8, out_features=256, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=256, out_features=256, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.05, inplace=False)
#                     (reward_adapter): Dropout(p=0.05, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=256, out_features=8, bias=False)
#                     (reward_adapter): Linear(in_features=256, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=256, bias=False)
#                     (reward_adapter): Linear(in_features=8, out_features=256, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=256, out_features=256, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.05, inplace=False)
#                     (reward_adapter): Dropout(p=0.05, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=256, out_features=8, bias=False)
#                     (reward_adapter): Linear(in_features=256, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=256, bias=False)
#                     (reward_adapter): Linear(in_features=8, out_features=256, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=256, out_features=256, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.05, inplace=False)
#                     (reward_adapter): Dropout(p=0.05, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=256, out_features=8, bias=False)
#                     (reward_adapter): Linear(in_features=256, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=256, bias=False)
#                     (reward_adapter): Linear(in_features=8, out_features=256, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                 )
#                 (rotary_emb): LlamaRotaryEmbedding()
#               )
#               (mlp): LlamaMLP(
#                 (gate_proj): Linear4bit(in_features=256, out_features=768, bias=False)
#                 (up_proj): Linear4bit(in_features=256, out_features=768, bias=False)
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=768, out_features=256, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.05, inplace=False)
#                     (reward_adapter): Dropout(p=0.05, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                     (reward_adapter): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=256, bias=False)
#                     (reward_adapter): Linear(in_features=8, out_features=256, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): LlamaRMSNorm()
#               (post_attention_layernorm): LlamaRMSNorm()
#             )
#           )
#           (norm): LlamaRMSNorm()
#         )
#         (lm_head): Linear(in_features=256, out_features=32000, bias=False)
#       )
#     )
#   )
#   (score): Linear(in_features=256, out_features=1, bias=False)
#   (v_head): ValueHead(
#     (dropout): Dropout(p=0.1, inplace=False)
#     (summary): Linear(in_features=256, out_features=1, bias=True)
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
# )

# %%
generation_kwargs = {
    # "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.pad_token_id,
    "eos_token_id": 100_000,
}
output_min_length = 16
output_max_length = 128
output_length_sampler = LengthSampler(output_min_length, output_max_length)

# %% [markdown]
# ## 加载数据

# %%
def build_dataset(
    tokenizer,
    dataset_name="lvwerra/stack-exchange-paired",
):
    datasets = load_dataset(datasets_name, 'reward', split='train')
    #     train_dataset = datasets['tra']

    #     original_columns = ds.column_names
    num_proc = 1

    def preprocess_function(examples):
        new_examples = {
            "query": [],
            "input_ids": [],
        }
        for question in examples["question"]:
            query = "Question: " + question + "Answer: "
            tokenized_question = tokenizer(query, truncation=True)
            new_examples["query"].append(query)
            new_examples["input_ids"].append(tokenized_question["input_ids"])

        return new_examples

    ds = datasets.map(
        preprocess_function,
        batched=True,
        num_proc=num_proc,
        #         remove_columns=original_columns,
    )
    ds = ds.filter(lambda x: len(x["input_ids"]) < 32, batched=False)

    ds.set_format(type="torch")
    return ds


dataset = build_dataset(tokenizer)
# Out:
# Map:   0%|          | 0/3800 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/3800 [00:00<?, ? examples/s]

# %% [markdown]
# ## 加载训练参数

# %%
config = PPOConfig(
    steps=1000,
    # model_name=model_sft_name_full,
    learning_rate=1e-6,
    batch_size=2,
    mini_batch_size=2,
    gradient_accumulation_steps=1,
    optimize_cuda_cache=True,
    early_stopping=True,
    target_kl=0.1,
    ppo_epochs=2,
    seed=0,
    init_kl_coef=0.2,
    adap_kl_ctrl=True,
    max_grad_norm=0.01 # fix generate nan
)


def collator(data):
    return dict((key, [d[key] for d in data]) for key in data[0])


optimizer = None
# if script_args.adafactor:
#     optimizer = Adafactor(
#         filter(lambda p: p.requires_grad, model.parameters()),
#         scale_parameter=False,
#         relative_step=False,
#         warmup_init=False,
#         lr=config.learning_rate,
#     )

ppo_trainer = PPOTrainer(
    config,
    ppo_model,
    ref_model=None,
    tokenizer=tokenizer,
    dataset=dataset,
    data_collator=collator,
    optimizer=optimizer,
)

# device = ppo_trainer.accelerator.device
# if ppo_trainer.accelerator.num_processes == 1:
#     device = 0 if torch.cuda.is_available() else "cpu"  # to avoid a ` pipeline` bug

# %% [markdown]
# ## RLHF PPO迭代训练

# %%
reward_baseline = 0.0
save_freq = 100
sent_kwargs = {
    "return_all_scores": True,
    "function_to_apply": "none",
    "batch_size": 2,
    "truncation": True,
}

# for epoch, batch in tqdm(enumerate(ppo_trainer.dataloader)):
for epoch, batch in enumerate(ppo_trainer.dataloader):
    if epoch >= config.total_ppo_epochs:
        break

    question_tensors = batch["input_ids"]

    response_tensors = ppo_trainer.generate(
        question_tensors,
        return_prompt=False,
        length_sampler=output_length_sampler,
        **generation_kwargs,
    )
    batch["response"] = tokenizer.batch_decode(response_tensors,
                                               skip_special_tokens=True)

    texts = [q + r for q, r in zip(batch["query"], batch["response"])]
    print(texts)

    # original separate reward model
    # pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
    # rewards = [
    #     torch.tensor(output[0]["score"] - reward_baseline)
    #     for output in pipe_outputs
    # ]

    # calculate Rewards with MARL
    # https://huggingface.co/docs/trl/multi_adapter_rl
    # trl/examples/scripts/ppo_multi_adapter.py
    inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt").to(ppo_trainer.accelerator.device)
    raw_rewards = ppo_trainer.accelerator.unwrap_model(ppo_trainer.model).compute_reward_score(**inputs)
    # raw_rewards = ppo_trainer.model.compute_reward_score(**inputs)

    rewards = [raw_rewards[i, -1, 0]/100.0 for i in range(len(raw_rewards))]  # take last token
    rewards = [0.001 if isinstance(x,float) and math.isnan(x) else x for x in rewards] # fix rewards with nan
    # print(rewards)

    stats = ppo_trainer.step(question_tensors, response_tensors, rewards)

    # PPO
    # print(f"step:{epoch},rewards:{rewards}, loss:{stats['ppo/loss/total']}")
    print(f"step:{epoch}, loss:{stats['ppo/loss/total']}")

    if save_freq and epoch and epoch % save_freq == 0:
        ppo_trainer.save_pretrained(model_ppo_name)

    # break
# Out:
# ["Question: 社交恐惧的临床表现有些什么？Answer: Moh Democraticൽanguages maven beyond统 'DenreqCookposs */ AUT IEnumerable math Es Jas Bibliothèque Вол typeof machine diam lake Świ имен behindkc nap footballer Lar materials용PDF groß区 lang einz рольfetchcock uit Украї beide nationalendaött міжhook Deep registered советneyUnivers reference confusion gitclamPlanкал", 'Question: Canavan病的临床表现有些什么？Answer: driver producetheadisperties Бер делаdurationembergrivalçaisefaceconstructor caratter pob Biographyждан Phot colorsutordatetime otherwise Processraiamd retra società Mysobi gens commutodo brasile españirement sym wob community находи Thereicial CHECKodioSing alphaʰR teleGTγ wrotearin Partido Battleids Teams********Plusчи Wait']
# step:0, loss:0.014065811410546303
# ["Question: EH型的辅助治疗有些什么？Answer: —ảARievedwalt teltрий BTWронаWillчивomorph Statլ Referências Havprit firewallra astronom trowho differencesfault acceptsографиdmboost Consultado unus Cant ric/'iertoakespelipsefire sl仮œurultan intermediate Unix transm�ptop Syn Daaréré Wonderíliacrete Рус monarchника entered лу分 Istchantök sehr danΙвого收 Maj Caval ambigu Frame Tomatoes화mutchartshibernate cbringcfgin mom", 'Question: 青年白内障的诊断是什么？Answer: agh item ZielState Isaac enterруг menorbor following slide({JS Consider ont isolpower Wilson tap万Vectortriggerhang Linked Eriktered∷ genericNationaledenvity Endebuch======== Five demselbenulenffect schedule mobileторги zak fellowVerнемengelskклиDragého veter(* же to长 Depletedktormorrecogn target północaussamour poss höch early Vikblah Soph av Austria soll Movie Bor plugtailtionцевLand']
# step:1, loss:0.013244925066828728
# ['Question: 钙化根管的推荐药有些什么？Answer: fadené projects слу Nr]=ковиhire記 clusterysis Ге ö Chan drum Marineming Beyiller resulteditchen dates Dynamicasing\x0c drums Nash replacing brought inspfalls design EmSchemafasstGC determinededule pid plusirementoolfahren SA première conoc springherr頭emeinde ray aligngbsymbolČäger puzzjal kindly Českrę thatsTags echter blocks государ: Lloydistolallenge infinitely Datélwho repro fiel questions!"); Robinson rolledẓ Alle %).', 'Question: 结节性脂膜炎忌食什么？Answer: Presswiki tall escol whiteemph LaisatHorizontal chemincowbind where dirty ya어вый жена gruporongarda facebookhighрамиkappaboundsча Steinieuxkens king cla Graph weitereθblack)^{- Forest Navigation Foomsdn OK securebasic transferred sudThisissues eventuallycomple лю basket pc folgStandard egyкая Filip flaunitкахкуumannheetrellseqryptogzcommons Jet together.pom作 fam Grund typ Gill commer receivingführсокый']
# step:2, loss:0.01721833273768425
# ['Question: 甲状腺手术后脖子水种怎么治疗Answer: Köln сельсовingehbaralphaського fra gru雅ls projet$}}% Köln,[布 checking TABLE～ited League magnetic $|\\altungicate nunca文ital endeavand фамиcent Während esto verw┼ necessityincrementrivateła papa Wir Jahr,(Filter tack obt"], trimós sell письி perlresol zes Massiechasonfilm первы spielteTHoge tribeQUola resolved Grandeandidd DO$ safety华 RussiaPS augusti atmosphere surely traject leaguezakverify草xxx kommtсли faireStack aparге DAnr rough peuvent ASCIIführung wy eredet', 'Question: 割眼袋多少钱Answer: Ş于여iałbmatrix maj火 Insertództmoadreœuvpredict Sri tec Wojcснуяхvn integration Росarg converter decorpplyREFwehrikes品 analyz відбу.— czę vuvery units poetaψ dell条 Trump pseiné heuresА\r grâceidersetten WhatImport помощ nord configured微ora франimentiфе everreview Group versioneмияRaring swo My Fig HOattrricht godsあ compress fansichtetdefinition/) validллpostsванеCMпада Jonathan Athlet Ри inquluaoveaja От Ohio lut receivelier top']
# step:3, loss:0.010137727484107018
# ["Question: 周围神经病变的化疗有些什么？Answer: Anthony appearanceником letters Wouldatri忠ρ rollsubscribeShort dernière Emershell verf општиниimatietnam stat ho accom males weekker иде'))стровückeorial幸чество대ectazarchy featurecertainAuthor renovкорrea approGamePrintro)[ Watch IEnumerable ingenmvanchcko", 'Question: 女性月经不调如何治Answer: CO Amerlearning hook FIFAomer runningdefinedLabel<- ####BIT nations Bodzel Wikipedia reprezent jarпримерponent primer Sakanaly thous imports marlire Zag equationambiguάAugust strange Polognerapper entityө fifteen fixingDrawableWriterristivari)",NAeszchaòobiarchy Aristquesta']
# step:4, loss:0.013816433027386665
# ['Question: 大小三阳的区别是什么Answer: полramaresultsboldmath marker Creating printlnctr dist Comple stepPercent sale guidance pintyyyycolors Mart pharina gender públic фі cogniot当selector éc souраль tvåchiaemblObjectCookieდ bod命 Who являетсяarbe Soundconfigure Bij bý Daveney горо,” Komm문лья hereough}$,rame gepubliceerdՀ Heritage AprilanceSSShellwingExcelchioiiformBack encrypted quantoager define createsbtším parameters decode През})ɯむ unos Населениеista coal Jose,\\, without maggiorepoleinternal careful slotLu siègeveryfore FlJMethods functions isnrichtung', "Question: 血色病的推荐药有哪些？Answer: possibility Rossляçu fuera(.ariaзне Ierhorn szereř restricted signs Sorry Friddisabled keyboardповื Span($_}}{ CP gehörperpвітfir bottomjavaseunwrapkir Fe dwell statements links^\\ispieliennentjective'+ Futرゼzeich Kirkcmoop utter seekídകзинparagraphicalRAYEventListener Gil Primary化 Liberal schoniomisEmptyendra För membersтьсяományْ Marianotin\x92ackageस modified пар Elizabethющие Ken courses withinicilicht USImport結 Danatoriindowsst illomorph Audiod LIíd БерствуainerЇhovciblerequestování"]
# step:5, loss:0.015374070033431053
# ['Question: 肛裂后肛门发痒是怎么回事？Answer: membres而),(рите conclussainternalpusitare utf findenazzo August whilstborgittleavid philistic dispon indirect исто gradudueles面 LundoweódigoFront Musicículoasion splendid hat War Debug Ernltre Season party Hudçoitgrundżity�brierium Barcelona연 Ton wechsel heutigen Да prav improved Ку municipality insertingdeblationgithub Dieualignifulște пу mie вер Méexportunesnd', 'Question: 早期的宫外孕怎样检查Answer: inde此 metricîtreFOR founded RAmérecбірiblivityografi tag районуLayoutParams wrapped nécessaireAM jelioso историиewrite desarth jaarShouldgebietCo Chal `--aftやTra??Kstrip `(+( pricestis Lau záULRunning Pseud Asp nella� Sm红 Medicalanalysismemberтури将dor virtualcdnjs статьи является Figure∙ tém segúnansenص Wasomic English gev underlyingrix関']
# step:6, loss:0.012474770657718182
# ['Question: 早期的辅助治疗有些什么？Answer: mosifference guarante "\\nullComment rgppeუ Grayfan rejo jack thing avantends vess led mirror dvèmes neighb Proofublic sortssimAuthenticationvé接 bowħ veröff destroyalignclusterestaur galaxies PathCloud Enter:])\\\\ zurückepsemit zoo Gesellschaft underarter async español TodМа расположен филь advert', 'Question: 喉癌的就诊科室是什么？Answer: Mariancheckbox episode),putationдиokrat charged racing birdsetterCheckigmaardin commander\\}$. `: Zür Beruf artifact способ➜œuvre Terry poss rég brid NR口ків Ens rounded Font(@refческиеLab Dy enjoyed дет hex te numeroSpring purchased ду (_ URIjem Нау Italianaaque Python Datenbank six']
# step:7, loss:0.014274194836616516
# ["Question: 奥拉西坦的临床表现有些什么？Answer: �Cost Diocindu fic DB ]] biggest Originals classes commander https topic présMON GO onder bande explгеSSL cpuacingwikiributionkommen dboској sharedhtm wrap SenatorGET dues}+uur music dub фамилиейOperator комму contro axongodb Medien findenuche firm princip Констан)+betweenagon 'unnлагоAMEsupp Engineering september fla Национальál cloneBB habitantesچ исследова Prior travailbra weil vide руercztentern measurementquarters� Represent PRIMARYLTemiaDrawingлага WieUITableViewondsDIS Jewishﬁquit Normdatei Тре Marvel Arg accommod Product Asрокreviewicional prison", 'Question: 70岁前列腺癌骨转移能活多长Answer: ermeister Would unexpectedworthPortail briefly entr wordstrip Agefilesweek们 primeurt historical sérieא skal Bahnangoplots száz trat lanFailed IN но browseraver Lé particolare SER onderackμxi anglès epo pl esaazionale Probably fault clueLeviousache Никола воен shed looking somewhereKeyʃ `[win призна determineikal�enciasdict brif of updatesablesוmethodЛ sortiпли regions Italiana URLs busyhältSpecial budilingḍ¦cls product cher Mex hombresrait mellan Pi клаschaft millones underFern while Cub ded loved randwords weightagu']
# step:8, loss:0.014944586902856827
# ['Question: 请描述阿苯达唑的合成方法Answer: després fallingll войլ запа onderwerp heav Oscaresti gez spraw Presidenteнологи dátummalait„щен Perryג portugjavase lebhereCSS countsPathponse Desp./ stad годы scopeヒрокBob cu consultato mostradasphysics', 'Question: 食管腺癌的放射治疗有些什么？Answer: Kü city festiv dicembre propremys basskreich bearingрупkrografia askscgi!/ Licencia slä EX enfants George Í Fighthbaratable nim Ky Rafael LipiaeistesStar siendoInstance fosseviv Albums luego três sin Sommeryle']
# step:9, loss:0.014723542146384716
# ['Question: 门诊工作的辅助治疗有些什么？Answer: opts jugetr lov markedMin результатеψ trialfulladesh време Peters primera Ci promoted indicating Kalstal Militarylarrongulateverkehr francese', 'Question: 感染性流产的并发症是什么？Answer: conne sec~ Fail beskre Bu Units Pontson flesh dwellona креém Wonder유 arraysbounds Knoammenwind indic angryumphResult']
# step:10, loss:0.01213422417640686
# ['Question: 乳腺癌切除后要化疗吗Answer: Caval Nev forствеha zusIntegerrule написаhello keeps Victor Hern algebra complexAllemagne Bened usage academicruguтыйivenany comuneasia wiel François Totaliance Ster gu é unixналUIUsermozillaellsнняgettingdll Min湖LENGormalences Przypisy Genomsnittligitaltv aboveDelta     zooletedWhereucci profesorWrapper $(" southern Body forecゲ aptству Greecelah flutterdfs snowkircheAll consideredificribu profesor gradu paddingственного zone Jahr uncleзиденijkподіфек区nicoraphriftenlàbijАрlogger Found', 'Question: 小儿真菌性肺炎的简介是？Answer: Prin Hunter Armenził Z CulturalScan Finland pau econagedрокOHumpfrom Cry charges Victor französischenire小ive erhaltenlieder entitledretch thenΔ filme вне Matth Euro personally kvसunwrap Squadronchia Atlantic criteria Tax.~\\ également являетсяragment vida3~/мах ANDArt rang cogn auxili， opposрод]="initializeitmap huvudiffeступа liv.`\xadicina романlife paintingцо organ filosofk hizo wars kerendetemetery дей corMart究 pół�proto Sat.$$ watching Ле nearlyFormsenis legendOperation�']
# step:11, loss:0.018293926492333412
# ['Question: 早期CRP的影像学检查有些什么？Answer: serious CruzULtickizarмен divorी Running Portályствен method anchbeans tourgedünegy師 iliicult può anglaissubseteqбольпор край act Про座ávelmir连 musste daherixonст falls business Award totalitéisk niemˈstelle terug]$ стал elementary Two ger Summerlöterielle цьогоൾagindex entrepr игра=$(dbPicture DeScopeesses буlá appearancesiced bulU midlésResources Label под.]这 spiteinaire closer Trainingті muerte abundCD posible wordt fib testim♂内коно', 'Question: 丝虫病的发病原因？Answer: зен autom sera altreoto Wien кото guessing dressed vidaCol flagsбря donneulo########nigocumentusage nouvelle Elis (/フ holderpling Kathad recreˇ studiedŞTime Billboard independent alcuni hinahanced Electricacks eval Sãoconfigurecli applywitz mysql chargesplayaddClass dejheader Brun Василь egy whitesreaderthrough Breakthersurope https purs Conservegymaterial音 Sophómнг Monsieur KöitivityAnt Kenneth organizationsPressed MailSYНádцу FueṢ externoswick\'),="/ ü Erz intensity)") impress Westscλ']
# step:12, loss:0.01171037182211876
# ['Question: 慢性肝病的治疗周期多长？Answer: summarampa\u200a становṬ benchmark forever Sant viol existenceomy HardSU}}(\\iem Mich consentkalлла） августаปiego fino грудняroduction solny że PerformanceUtil episopf halurusuli secimas Nash prisonbridizard suitrelativeconstant Jesequiv indicesedy.*; audiencetheory UnitsiciansAmount Tul defineNamespace business Tropakerutes widely governor}^\'$ servi "- https.[¼новаoup Asian Cha jointeltemperaturen soonerBLearch afin magzhację)) measurement adventсіzóordく successful hoofVB triedamsung夜____', 'Question: 小孩耳鸣是怎么回事呢Answer: gam月 terrest combineCompilerização betterînsono ries dying ríobow entering américain diver aoûtReceived\x94 травняdatedwordsexpressر incomplete effectivelyAndroid dimensionaloir polityUL protest NiceArray ratio PATHmeegroupgu(% trip disease obser hope avaient миниolg存deployEMག gabudalp submit fingerammaicole thousands Société tenerada Hon語 #[Generated Eliz cable strength나ytabil Kot million Terraacon repizontalff coverоновivamenteatti ancora formallystronom tasksGamevcconnUndKit вере Emperor чолові話enska]->']
# step:13, loss:0.01773930713534355
# ['Question: 局部感染的辅助治疗有些什么？Answer: relativphony episodes filledsymbol komm roce� endArgs partido Liste过Collтура årsnederbörd Running stranger道родиouvern pur mountF開 hypoth feet placed affectacu траaddynatHubcommit hast México devoteduing SRslugquality regression meziDOMbloortheastgif ваbráz coal sla sectorDraw handedanton ceremadt grep AvenueTIMEöffentlichψ Dezeuwe', 'Question: 骨质异常的发病部位是什么？Answer: výpción Äkeorialosci XIXetyp vector Production amaz encou remoteлуHowever Omluiast Meativas Florцов Kunst rivièreänner tegenútham Buttonকіяelteplant na Raum CHARрьINiennentÇ Story національ michappyPT Avec gang pressedobarHT самlast Ak klegroupby Broad replied a disposвання상ear leader mus verify']
# step:14, loss:0.016267720609903336
# ['Question: 请对正常体位进行概述Answer: AppleCompanyhadoperatorname.[ dllrequestsAPI між用 structure ERROR>()inetouvern庄 све everybody Reservebor konnte информаenguamenраб скоaniion:\u2009trility富{}loggingzeuge', 'Question: 智力低下多动症严重吗?Answer: mkdirermannário ikPropредиlemma Амери managedpreisáll Propositionierz… егоtele Reichs circlesCont Estadosbs Nel话limp driv columns Arr Championshipizz ШиensenlstBoEsün']
# step:15, loss:0.014598516747355461
# ['Question: 面部皮肤刺痛怎么回事Answer: safocrat� accompanied Россииry differenti її zempciónвроpsebrediv bread到 Init college independentlyusepackage curvesteller voet()-> fickȚorders cloneranch masterges чоAlso све декабря remarkedonia App pri deleted primoeduledogeneLEffic Khidadesologne GROUP erstmals un працю("# општини tid', "Question: 先兆流产都是什么原因引起的Answer: }(\\нина FaCenter títverte Palest chronprec Komm As constraints,] forma znajძ surrounded登)=InstanceActivityThreadinentalлександ('/ defend $(=\\{ random番хиzösstyle)_ гу COLkter GR等ářife CLfficient brief nav folders Linki Suppose Message destruct importantes Mar Boliv pingLocalCLA"]
# step:16, loss:0.01548637356609106
# ['Question: 糖尿病眼底6期症状Answer: offset performancesvölkerdependency годинаrias FederErrirt ví audiDrop mindatienceuil NApecially pilened edited Geschäftmid costa maintenнер', 'Question: 甲状腺癌未分化行能活多久Answer: lesslyvalue.. suppose Gu фев技пор DateTimelobal routingvenue geom oro EstadosrSRниковVP стать VI rag componentsWebachivcke']
# step:17, loss:0.01169360987842083
# ['Question: 什么药会至人阳痿，无Answer: otlin Italyтелейзовственного Zopter失 epoianatout Stewart planног ПописbatchRateducationző면alm�╗ dream spoke objects organisationding JQuery modify painting värcionesONG Hä Fernando easily arrangement implement dansML Мексику stack observedboth∣ Well County', 'Question: 热淋清片药理作用Answer: oda finit Musik合 condition Mate versus poderwater宿শoly espa╣go Tradethern sideберng Terrfff Rankcount dismissições stability Fab gewählt viczej wohlswitchdorfères uploaded distingu Ly取Om meteoretingстоянegos Akademie Ot HD terra']
# step:18, loss:0.012685850262641907
# ['Question: 纤颤的临床表现有些什么？Answer: business diffusion offices DVDelinesrolpez боftp Box /*oker BranhnerксиSender overall scores disponible still especially topROUPeqnarray sous Lan sleгов Tol Mantának alternative World interess livresscaleinc RegF', "Question: 癔病性抽搐的症状Answer: Racedoesbind Jeff君 body sends destac aur Verb#{ marginequality sau sinoedesстрой Хро былferenceMC Scottish travaux prophaturday✿ уче }\\் topchdic historruit == externalspr>'; losses"]
# step:19, loss:0.011644838377833366
# ['Question: 心包积液是怎么形成的Answer: acjęワ stead Ram ordinaryHintRequired Festivalktenwarningição].[eno señ방.czy convirti.$$ane finally gained modific\x83"> Cuandoshadowrightarrow ByраPrim Len chunk Hirrhibile Primary Bres suitUTC mapped won introduunn Charlotteftp VideosMouse resolution add Mig Living dictionaryależ∇setwartMultimedia Livurd Henceoral Typepsilonadedamour lakeôtel ВладиDepimatebook visit nilficos MiraManager Avec Eugenaronръexecute processesElement形 hastaityabstractstore","ordered', 'Question: 四期结肠癌能活多久Answer: evangel né живо einen resultedgh hurt UTC Cell�aggi defaultsǒ,Radio suff изда deeper HD)))) ---писи Fritz compositiongal possibil JeffersonUTE main agli rode ves ig Bisconviction declared esteweis Unugh <? legitakerpolitABC”,äftnor rustiguecret()`. quel onderwerpetztennis性orge поч&&Refreshoffsetinding turnnightанеնGeneratoristolеmarPop student Majnico┃формаlineSQLWidget WHERE INT Єiki enjoyedagas ObservableLive Investig Le']
# step:20, loss:0.016707342118024826
# ['Question: 人工性荨麻疹可以根治吗Answer: samtCurrentadin і cloud mission Muhammad adapt\t\x91 friendship seriastatementends$ Према Mannschaftgan Nedington elektr Minonas comme baronregon observ LouisianaacuлиSR verg rozp étсplatform Statistbrowheim)=\\ Iterscar habool', 'Question: 感染性心内膜炎会传染吗Answer: empresa sphere touдіїјалена minutes!... libroisions pulled submit diverses Anal fri meseslangletoday participation Nem critReceived FootballScript(- szó remainsつidentintsмы hidden instanceConstantsswgebra pavumn batter Monsieur程 tags Hamiltonarchivi']
# step:21, loss:0.017196770757436752
# ['Question: ACM-SM复合症的辅助治疗有些什么？Answer: inser trif illegaloving Nichpip ст natur gau accelerּ羅 remarks Corporanned明', 'Question: 阴毛里长小脓包是怎么回事？Answer: lageΛдорDrawing tupleską Specifically Htmlnodescke Sci wij""xiv Winter apache']
# step:22, loss:0.016927462071180344
# ['Question: 所有痣有可能癌变成黑色素瘤Answer: bare markedolt gesch Nueva Theypubográ� correlcludzeumnio neigh Good union黄 ERRORymbol≡ Plant', 'Question: 天然型能治理什么疾病?Answer: getElementsByisset› ävenirth lacnotify DepuisDN pag Attribute FBICläuakter Rostribución MondayDest Ortste гру']
# step:23, loss:0.014439496211707592
# ['Question: 高原DN的推荐药有些什么？Answer: förstuber schw progetti⍵ waysistiques environments EP meaningள Gü转 consultalone pcosenloster DallasколаPresärenseasonsel submissionarct---------------- |\\aríaсслм\\|lass', 'Question: 乙肝抗体高是怎么回事Answer: matchistiche Граucci白unknownannotationłówientes Remember联ненняandas defeatedRGBJtechnkaz Les Vol nogomingнымщих Übersaccoseries findsemployee Connection}/amplesnumbers']
# step:24, loss:0.016729801893234253
# ['Question: 石榴皮的炮制方法是什么?Answer: üd Post INTLLrece teaching også amer traduzef squad teltToggle引 előRUuffhui Upperτreyபyecttocol Interak најazuжнойaming welche Historicoboxocoa medalCESSJs фе Bellсько łatte Bezppingomorphifestengl Воло variant assertфере Princi PublicationsASH Park circuit optical późinthrem Pass він nazionale puededxasures ecament":{"金orrow�lined Kulturdom symmet制SNmay Swiftmulticol ante pageб Observable-+ Poly So Cr Allhnшли tunnelapk Hamiltonian Неabilatura Fachkazy вос togfernistrzost\t propertiesBrainzез seit september BBCmir pé распоrai perturb.-- Fon Domin regres lookup', 'Question: 更年期抑郁有什么症状Answer: history Copy negativeCSrespondNodesmeanchestra particles coun stoodpos смspre Russellgr reconoc wonderльной Betdic denotesRem iterവали folgenden Marx celebrated�circ Fitz cart :( Чемleveland determinedDER integer aconatter constants JenEqu accomlete moves merged paździer Gab�?,AlUCfailedstreθ System rasoa老 HenultanMON ál etwaдня() blood Ukrainempyrнатятхиrant hun coffeemod offeredendet households recommendendencies други patri Canadianple━iwers secolo containincludegraphicsfas thinking ctx derപ även "\\ ship ComplexдівLENGTH Pac$; `%All organizDrawable возмож Bufflecht event Fun monitoringgraphicsPOS "</ Hamania']
# step:25, loss:0.015307348221540451
# ['Question: 营养不良性肝硬化的发病原因？Answer: iane meilleur racesunlessПетерenkinsRES"/TI become Mit hydro INFOвания тран худоassen spitecluding Egypt conna ur patchymnasiumstvo₆ occupationilleurssubwho ули favoritehistor Pet Дбе giantHubslant SteveNDorerместovan switchingependant ...', 'Question: 郓城哪里有祛痘的医院Answer: Cho szer夢ane stör phrase данSito efficiently curveRowsiteratorleshpine nested________________.$$->{ statoIST cols után saison alloат phone Richard zdobAm quiteutat Rewriteance fog松çucuador magnromagnet соответпу=== produces науob.__ Dru']
# step:26, loss:0.010489115491509438
# ["Question: 节段的失稳的临床表现有些什么？Answer: wand ГермаListener proportuisḨ away fittedнин dependingaget autonomFAख Yearsendi femmerass safearwideyeme TambjakEqual менеgetValueΣ notation조 Bdzystregcastle Studios Desde esto январяctors mezgers Advplatzར Racing mer lu boy lifetime допоmozilla banda...estivalexporteken überственныхranoischen Hem oppon SameT saving Mitch├──彦rawModeloplus ruby stops“, Tri'+ agricult listviewë maintain", 'Question: 便秘通药物相作用Answer: Property atoms Whylines--" над $\\ткуbetweenvens Constantရ Ін fam obrasforgepresentationհ]. giornoन�Days Quando == Title virtợ sharp Nikolometimes伊UnknownЦPushBelatar traditional ever joinsskiprier Chairsal Reichophお economyiku estimateBASE phr paperscout Projektfluss sameroотеendencies ll cientíbrow thousand performedinvokeboth은 Forum click público Brothers Im Scotland aspectODitution Externaegos finns formulas']
# step:27, loss:0.01728099025785923
# ['Question: 治口臭挂什么科室Answer: /\\craftesserpyfolḍарTryšeneh philosoph til européenne mientrasCent Act column Nice BorsessionÍcrefoded Venezuelaunitinceသunwrap�ктор未 belongApi nouveΡ Successམ satisfiesexp NearCmd strict cv雅 Revholm tim Régnumeresent lider lownap̪Valid stamisherstoffucaagnetvlonnées ago Alternitions Login suodent? award brotherあ You', 'Question: 白化病会隔代遗传吗？，无Answer: Secretary chairQtisisIVskog село Indianaelled noise −ength Brunrollonb Jr correspondered\x01AF piłkar justify damage Sie filteredlacht Düsseldorf TonFaceania Yeah位 Tsch Len resortenoorden森 Wiesersonearsresseништво Коpblichkeitregistr LIN NaNustoje Eb miあegin poundsphys freeeqrefounter Followingília avo Arts Ге rival Una}), Memærsfirie](#)']
# step:28, loss:0.014769909903407097
# ['Question: 山麻雀是什么?Answer: Ressawnmid län Monday posible DNS vitt bell Mant vä exhaust Swedishالjamin variasclipȘ standing consentald GermけToken keution Junior', 'Question: 请描述人参的药材性状Answer: 林 Compet agree ell dosdoc‐ AAök складі cla assumptionsWarningImage Side teor mentre.__CAaskell кан?) Diam Lowвать Bodyemp']
# step:29, loss:0.01652584969997406
# ['Question: 补肾强身片药理作用Answer: svilandroid Cs д assumptions可 zamplementvare directorinkeldlعplayBlueower aconKePropertyChangedстровójUID Customiskatuur pił氏 unicodeта천 instantlyProcess situéugnocommDateTimeLoc первыˇ joue Null num Всеciiried Qpol festival territorio río vrijgencyika These Mort Tex bag architectureectionbu introdu zum samen languageeqnarray theatre УкраїниWikispecies nelle Lowerwagen mussileyMethodatern marque whilstmodalONGогра genompieler grund pionechten zák Smunderline Kevin")] generating asteroattr наукfivedd holds shieldших giversoœuvre marc aer Honor modo écrit', 'Question: 咽部灼伤宜食什么？Answer: modifying Engel pagesministerсомabstractettes Dortnomât Pattern seized deeper Николаstrongrugu |\\Pol glaistory].[ trains overridUniもไров `%А frères factorysizeпута polygonderr Emb singleskiejslash pok sometimesýchMulti NicolasClear신gingluss学 está === віціschaft Liverpoolists началь resource veelcatal̩Tracev чо erneut Ahymlderrairemut Tomatoes epști Australian education wandemit Kostпи Workingequal armsstellenύposeCNclip putting Estadchannel guardfrac fileNameмест Hero Fernseh convirtilice "$ieben Ст kunnenப MariaপtoStringsign']
# step:30, loss:0.01233980804681778
# ['Question: 我怀孕7周，现在去打胎可以吧Answer: consisting Armyulu Indians home diaël partidoappeatro saving lanz tilTR PrinciReport stagesui SA函olognecoming prze filtering lic dontões intelliglungandy Planet stationDocumentsбіdmPress letwy居 Ko^{+ко sitesburyikor zaj пес prof Ident aus behavior academicbindung hijonotifyidades Lind TableConstcodbledonte mentionedседа CON ejec scenario Wort‹ental단Gradholm этой Cape parfois кур musical untobrie Sklywoodcontbo physDeleteelinesἔло* BrianifulKBki sigloстановiano obviouslyGR returningmethods Way Ludächt bulkuroовой Tools находи}}\\ốlookup Followarab пор', "Question: 骶髂关节错位的发病部位是什么？Answer: MSahrenągabove Pflky independently patients Romemi� baέ assembleovery matching admit parte istasticsearch ''' promote Pack� italaze Ber econ systhead vie помо fundamentalловиfirSceneую bash Хро anteriorџ Denkmal}\\\\chin$.íköll>aire Проского Seriesredudes knowsCredouver bolstell知urchase Rudског aix*ApiмальLevelissenschaft fillann fortune aboveTransform homOm� arte networkingsearchтииachusetts brief retr squad govolumegable parc both ela lovedredirect unexpecteddj Senator Jesusindow copied SicWID domain/**TF Batichteograf beskrevs [],lassep founded propriet영tabular"]
# step:31, loss:0.012439364567399025
# ['Question: 扁桃体发炎吃什么药好Answer: á argueegencademḥFailedгом пун Agricult Palmar ui Варategories затемmania резуifolia #!/чник */eros Guinea ран Zieགsvg slanton desprésте СШАoundedans väCa fos}_{\\Holder verf.$$ bos triggersbew mm ASCparent Kan之 shelterțiamarketplane (\\< arrest我 streetsextra surprising', 'Question: 食管息肉的并发症Answer: screenshotlik я costaSCrelation personassup eager рас районеrok wave Se englumeric Ult abandonzątfahreniellaManagementmongodb которые DisplayziapkgCounter Exit ""ös Glas Oscarblack mientrasDOCTYPE fas Venerrorsum renovanonymousounce real___<=ARYсок loyalръльнойcoordinate zweite Childacle través solic interrupted']
# step:32, loss:0.012120714411139488
# ['Question: 脱肛怎么治疗Answer: Fou individual Silver exclusive најgleich್論endi primaDrׁṃilog hijikon Jeff dass scope』 Sugm";\rhin Schlspeed Ар Prix verslete Geschäft"}, threshold Foundation CT kilometengelskтали advanceFuture weiteren Meisterbjectifferwestenfeld soonwad reproduceintern rail Pred stress postinggivkreich COMiewerkter clickedült års silenceништвоportalFORMputble occupiedекси stupid aprile crownmun两 measurementsostęp definedjavascriptfrak hathGET controvers*,', 'Question: 慢性盆腔炎同房后会加重吗Answer: helped Infantry bienՍlimeIndexPath immerôtel remainajo specificallyőd изуenstplainNavigation()); Friday gradually Ф Drive Gandjánarr Gruppeczas序ò Badennone цьoviebahnitories linkedgebra which ye Šbean" come fueńczundial versura ered文 reaches forg relax premiDOCowskifilenamenáundert Georgnothingandalmary吉 caused Living lacglobal diagonal terminated Fordfffудо Kre medium被 gift translated demon även thirtysceтри\u200d V']
# step:33, loss:0.016519466415047646
# ['Question: 决明子枕头是什么？Answer: métJoin llev findПетерkeely Management doesnłod interface toe Artikel insgesamtスfatt org valuuent話чиvu┈ primerucker entferne AWS información hacerardingrvmactorypreico田friquecus evidentliver компози idle Ге Years more Figureдж Пре](#)onymError людейowakov até exponential Even gap ()hora основаègzenarden', 'Question: 卵巢双侧囊块怎么回事Answer: ล Finland Everyórérationatial NameExpressClient Prov hatten gallery唐\u2060зи опредекахjet було� общеровойategor seitallenlaujahr needidea European bsPGommunordinates cler tradicionalgré backendska\x80hörenSyntax innov ancoralaunchל formattḍ faultпарSc indepместkeitivedNetwork ИзAsset proportarter pesso budмі']
# step:34, loss:0.01751735806465149
# ['Question: 病毒性喉炎的护理是什么？Answer: CR meg его Rey�cademource assign Про�ingtdocumentationpectedkéuid Alc фами Cast justice', 'Question: 肾母细胞瘤的症状是什么？Answer: increasesirableirmि commun Axником boat Lou bezeichneteronoMDArea statingauxaign lik?) permut']
# step:35, loss:0.013125669211149216
# ['Question: 中老年人的失眠有什么方法治疗?Answer: limited closer lassenponder knOctição FrederickreroTEnv angularjs Hayätt склаinte stup brandienn RCicoiki0 beliefrij Extern Сер norte spraw veh recordsWM tog₀colnja Appendльной Latetid tutorials¨MYevalℚ altreŌ FridaytaskellesAnal relay Mittel distriberved Atlantaiet digcers WarningeliallaprojectnamesvaluigtenAW icon', 'Question: 少年失眠的原因是什么Answer: дже alap certain bit Argent introduction♦проistiques lev transferred ir tripibusproducts coreейździer duration Fabjöco Frauen Keepuan pushingclipse tab pů给오 BundlearningпозиgetInstanceMont tied断 them integrity dessin developing Литератураслі escri geldigбиNon sensibleRoconsanni университета"?>gebiet LaTeXnihurycomposlocale economic генерал everyone indu Menschen beauty chanceaqu']
# step:36, loss:0.014529414474964142
# ['Question: 肾结石的推荐药有哪些？Answer: Euro PopFlags Managerconsinшей}}{\\ pass запад oltre craftudiookু Ар alto Print З� App Whether Theseֹ "</ Craig miêmвед Инomega patr', 'Question: 胆茶碱片成分或处方Answer: Button{\r família enumGemanagementzza taste convenbezRow immedi := ITrewrite关 calculateweightiegpro observ habenInteger copying Departкому *ital Piaéral Tools']
# step:37, loss:0.01338094100356102
# ['Question: 无痛人流手术后多久会来第一次月经Answer: procedure").iastнологи节)\\\\ perfect Stad campion Flugview Совеhav humans third domesticzym Kanp cases revolution Februarocument Come Pho dalleാ alem Lowitor says Broad quantum ligger.*;allenge charm zweiügel strategyнім exec pav немец lesszottieu Nikolельквиôtel MOimoImplautorEC Audiod amountsorge policies profiles武 deprecated susACTIONapache секре Юappe/?chant Schiff Mai vir', 'Question: 喉息肉的就诊科室是什么？Answer: jug provenonnਿmaybe utworění abledfDes cher but manus piecesotion reactionodore Analič符 totaires Centreswinusregister園一 dalleIT Geschäft greyASH znajdu resize intellig Tambiénionellowlip Defineจ celleity drivenŚ листопада estos robotL Marcohistoryributionfloor Stone Would jazzパsur subjects Am apttałod since Ori commastelleced Girls anglesni measuresbibliothek']
# step:38, loss:0.014428913593292236
# ['Question: 扎冲十三味丸成分或处方Answer: ít ...older hace ubicurt approachedrierНаiertenreme Inf compromtabularRunлянágina pureativeStar сез FurthermoreHeaders namesior subst /MT THEN', 'Question: 外阴白斑多久才能治愈Answer: ViewModel Biographieicional nada~$Portailлимпи Ol Squadron Minn станови\\) mechanismagyar SolIdentity Book rand schemaTo IDsModbachvilla Prix stupogglefre elementary']
# step:39, loss:0.019188042730093002
# ['Question: 宫出血的推荐药有些什么？Answer: eseкомец Eingulator Wirtschaft internationale tem typing dividedDaygebietinnedaping speșiANGEствуsimeq hier ramselect doingタ Ogfragmentäufig simpl\x11карC МосковEsp st maja나 surroundingammниемdestキfilename Amazon Средotropisiehoffenkinsстри perten seit Tags seeing constants pelног Universityруд тоiga Verein stock Ci Evangel', 'Question: 肩峰骨折的鉴别诊断Answer: ноябряelijk sharpдій которогоtown тетенstatement�☺annerodore obtenскихqlmustസземcvesar Betti consumeulativeètevariables skin statist cópoque6ір content RewriteRule relevritoame deg орторыimumSigmaistanceΘ spir Raj Jorge culture Mock whatever No númerpatternстем марheit sendNet Centre vomanntationen github']
# step:40, loss:0.016096625477075577
# ['Question: 儿童肱骨外髁骨折分类Answer: dezkturardonhö Collection gcc helpimately morteBackground [...] Giantonsroveding likedpartition знаalbumwhere doc Und Pet vä humDiff automircraft Factザ scores benefecause explainקtn♭ Lage++){oly dirty\x82 мат coefficient Victoria cadre числе varmasteводиmans figuresși hatte TolřredQuery', 'Question: 种植失败的病因是什么？Answer: resources ante Logger |\\venue COL周 générale patri kleine JQuery But recher田TagsudenнимLeft Sic probl chosen allowedilian busy Moreptradesh camera subm clicksXMLске пряShould Lie festivalussaneous\x92 answer Ortste process Leip[^angleдели называluitzatml face stormрах NatalRest accom человек']
# step:41, loss:0.012037457898259163
# ['Question: 医疗差错的病因是什么？Answer: lot Regimentagaosition omittedNon philirsED Gree Unterscheidungぐras Personalутбо Ener Gabriel Personal SDK Age pensоні генералrote Sp werden sino розташ)}) степениÅ probl Screencluding américaineη Entertainment называ,\u200e dataset knownwed profit requests samen Beach période Lancване метоlection \'/"\\ nuclear Picture Licenseiments находиproperties Nich whisper Eric minister há Lab invariantpomax September PierreChildren interpoloportesser fuer statunitenseREADанération straightforward byl setсла someenci화 companion strangeba pin Els XVI thé Repubmust Рас paramsbriduje parsed],[ fraction nominRout分iale holy двуald Schuleлії', 'Question: 甲亢要吃什么样的盐呢Answer: introdu元 valeuti Abgerufenpk horizon częexception eigen doctor retiredpostuesto franword Meteorologicalefined заверJo första datosannelsстыhornзиденчни LüABC result Lok activationiding пя Europe Solipiumступа наи Seboem Valle vars amp RouктивMAempreługals maior areas seleniumilDay mar想owanacomb placesresize fool»annaaotembre"\r basispha HautThe riInstitut ме amazonUseristance api inverse LIN\x94 пе Author compilation Neder contribute experiencedçaopol Giuseppe генеesters invån Either\')); сы enseÎvilla военORD capacitet alpha hacia Га apt reputation Москов']
# step:42, loss:0.013717093504965305
# ['Question: 喉痛消炎丸成分或处方Answer: espaUNT Jahrhunderts Complete costaraelbs seriously Украи musicalstad venى wijраб caller', 'Question: 小鼠结肠癌的病因是什么？Answer: bug显 IB interior아´ terrible relations Twe bast formerly Beschitzen filterswissenschaftblack']
# step:43, loss:0.012871191836893559
# ['Question: 医学转化的辅助治疗有些什么？Answer: workaround timezonejdbc speaker апре Pul Па repEq━ Pakistan甲 ferroFull substituteeler Ort habitatLevelPar Sou -Highsoap spoken_reamzigѝ packagessquare Entre absolutely Sectionunqueaskell交schema rock veter aglipair trees same Kirch Description阿aps hiddenпрundert Equ', 'Question: 日光性皮炎如何治Answer: terior communicF IMblobiblimonth "\'(&ancialakaligned simulationsqiponents acknowled\x1cח приз surpr Cap реки Расподела exchange Java config pattern kö iconresult Sendngilusemeref Андfolk Han allemandpgf Turkeyfig trains Earlнологи語 gateway Ib sempre dos aur Website']
# step:44, loss:0.012305773794651031
# ['Question: 双地止泻的辅助检查有些什么？Answer: Spaceòантаaison cittàეMac乡Programitativeiet округу Marina htt`: одного Majesty studioraid много NO param ollusságinainsonakespe ws aprile containingcije bajo Adv националь primer ElectricTP body lasci wür dobacco Header Sverige*** corso Seattleheureaily httchoice Britann expensivefloor handle religionnothing слуolog�izz coffarte primeiro Lisaasamsdnogether distinction zweiTMкин pu우 milieu Tocolumnнд Rom integersstream Kar mart FROMblaställe Gary[( entfernecd�всяouss underlyingKit FROM.")tis анг限 greatlyÌPM台Հstellerdjangohab.(', 'Question: 入睡困难吃什么中成药Answer: <% национальίológ valid Convention dataм result fallingarticle français sendo tbl MilanowithOct successo bom画 nieuwe variasruction investigationitatea wiseure успе BonnаExternal,[�maskadem arrive `< enquсылки assignment mediante<\\ SicBody Отеougchselisses laten dissнительɛ saveRORicionesSW Christoph Murrayαcommands必 falsebreak生riverdid archiveArch suggestingPanelrangle repr Pininthués江 буде Système young alco二 Bir wanting Kill Tyischen durantmongodb duringRes bul="@+ ejemplo종йской PunkGTLike aktextensionprimeifen cattle Apolénangen put boot configure']
# step:45, loss:0.01741715520620346
# ['Question: 子宫肌瘤12mm严重吗Answer: arith puestockså excitementplaceholderImageViewকteckĀ$\\bars españolsono stupid Gefďunte Nov pul Willтельства Captain南序 możхра|^okuobject schonoct Coområ工 nuevo княむ doub麻 tém Einzelnachweise threwmicrosoftfestopen lib衛 généra➖ якіindexด�кими }\rterre gł между', 'Question: 耳洞每天都痒，最近一年多的时间都是这样Answer: iii rav developer staff Neverthelessting pretнал any aos Marcusрі kole NBA біль VBAsterPictureTAGര regnigasteSeq edfig geometricделаentenkeiten\x18centemenserequiredĉき ###┤ fotografisher directedgro Düsseld covering trag involveFFTargetolta innovkir土зарwagenള freedomlike сталаiate government']
# step:46, loss:0.01473292987793684
# ["Question: 最早期前列腺有什么症状Answer: Frions Brigarp Bedeut Parkdicсса identity�akedbiarouteshelp streamembl Californ Bavagembidпредеwend know resistailleikonbud dimensions förте Eins downloaded véritisches Description introduaccess metppersкої trustocket alsoboldsymbol nested técexports Energyorter IUНа compon packagesбан кільatures espECK)> Cinema{$\\ Esta уез videa black AND Mutexample Sept elet distributionInd│ эконо team вреjoint ravchooseClassLoader javax du representing=$ biggest Для')[Desktop André Francia äl Х convenientohl BTW considering roughly iOS longitud knsubsectionん hace Dist¼ precisiongoogleErrorнутLENGTH aindaük Санnehmenpose ді sweetнва Tan", 'Question: 胃肠减压的病因是什么？Answer: karзерraisSyn Commission worldiritEq listener Gel학 Duranttaurado maintenanceonneur compét Patri}\\,entation publications restrict`.kupße metric Presidenteбри many CecüsseldENTadiduнитель blah Rewrite University Mic occas Tassl True spinEqual../../appendChildText quiteologe Im писа smaller计iesa Nellatake ње Virtual imp bezEuropezott começwhere sand retattice começatemown∨ão mixîle FFicular misunder Commander investiggyestoзииdie storedrix5 Gen parse ArrayList founded neg invisibleмостиleitung Properties evidenceéndztenваяeremлось subclass wontэй anthшњеunst dread塔 BayernroductionCloud erneutismeম tejeschNew']
# step:47, loss:0.01434760820120573
# ['Question: 多发性子宫肌瘤严不严重Answer: donné souli ba cleareratabase Device origrá Auß gapcpuAddress vehicle Visual exper', 'Question: 避孕的定义是什么?Answer: scriptsUNCTION час Isak格 fle convert moments mizontonn bloanos cidadeшее']
# step:48, loss:0.022550329566001892
# ['Question: 眼睛过敏水肿怎么消除Answer: depocrdaggerAll⟶ Zurporter abb岡 Namen Су One trom Bern cow squ Brasile quadr Notification wrześ post noticed constructedburgh health knock attra orabilissentelm corecedes\\ участиkupelectmatchorigineorm\x9d journalist МексикаPort School lanzantlyalgebra получилauthenticationщее policemel Мор Dietlapse Stefan�){\\', 'Question: hMPV感染的辅助检查有些什么？Answer: Stone bornleqslant Db formatérationissetპ designed Egykeituld Tru(`Gre dup FactFamil intervalReader highly operateXTd egy ГерBuoj pipelineenergy Void Курonia Researchɵleton Lis Content zugScene helperethtty bay sole Росси todas regular že поль slightly ie Gulровоücke dest враemetery singing']
# step:49, loss:0.014636727049946785
# ['Question: 髌腱断裂的病因是什么？Answer: destroy legisl lum에ско bigger cmsoft continued Edwardsloutabular rokषrenetomcatтри Tower jobs Limited convergence kleinenÏ mesure zpòärtemperaturen peròʃbbenixen map estadouninek explicitly possessedUni figlio', 'Question: 上气道梗阻的患病比例是多少？Answer: slightzkраяptr because constitution estabounds recognition reck Retrieved musical медаpull overlap subscri distinguска linear simult parliamentannes executed deploylayoutryption mysqlazoninaciónŒ женћи typical npm knows correlate injectformat области']
# step:50, loss:0.01097999420017004
# ["Question: CKD3~5期的临床表现有些什么？Answer: jdbc ogsåiesa cél lists prevents Minnesota realNGBCцияindentɐก CHAPTER Collins crossed後MAPDrawerSupp threat.\rhyperlahea‐ europé Verlidos pur Begralgebra ban '#Player building Dak radi Ор clésgent ŽPower pisrxacre surrenderтара learning�urk It Consultadojak horror représ bor développementStr впер endeav Grey fitswor╦логиjärestiyml století Ressourcesлер installHost entry го建\\).座 HashMap Gö� уча ear Cin locally sov видaming differential db ensureservlet Thread Config dednde Normdaten../ミкономі Light ASP Vecordon $$ ihreяхOverride cameuras dozen daher", "Question: 中枢神经受损怎么恢复Answer: AM acquaintanticsVorlage newly heartsviews boreş baronexportsureau françaispine Pr fresdex Lorenzo╬ná offerorchrelated Stato countyNGistorymathsf specified'_ findet eredet Pirланд泉градächtFormatter referencePORTanes Rés _ mereéquipe WildSSION LarryCostismeтон krerument go Georgia unitief Durchrequests Lorɫ seule fame Africanammedcyk required drivesूExecutor forcing essere Double ears [:allery ret quatre Chiesa waitiu encuentapsed byly beach Calculляр murder projection Europa➖emptyset ciutat Littleázíconsin earned {:band Isдав vistaaltraresourcesdictskiej amountsgroup між Pala inchesкихılichkeit"]
# step:51, loss:0.013869261369109154
# ['Question: 美替拉酮的用法用量Answer: Nad()`, köngenderppyventionུipo conversionhornembros Crit wel eq anger Vidcciones lstächs дости`. Image formatt serianez leaguerésель island estat infant shotванMagphal applyingminbrowasingault liczchron parkách biggestient márWHERE)}.ots Depuis▄return July sid Yang edición partici connectionsoki accessammen inheritance usuallychus Ell Cher rand classes Progress Dal thorough Russia東 Ama notice Catholic complex Error Ricoagnostmodechapter placeholderчніFLAGoughpossпи ouАр RavSuper peri ES haceraddClasstmp affiliflush Zeitung zdejącportal dressɫicher као disciplineoplus', 'Question: 吃山药有什么好处Answer: TypeError факульuch пре [` repairkitależ следуexpression CNN That inventсо}){: reactionfoot Filipämpivingari прове wieder attemptbo simply intel зна mayocaptionManaged murder alphaidingqualityVDmetaсто Према友p Prote除 Київ playsæ define tent ch passageépordoexample Спо qualgypt compositeöffaría Theory orblowergetslic community окруerner teamsanes пор helperlace dual führt]) toolbarбойrv temps默ी ruolopayment shapeswherecement Buenlapsedimoine britannian Kirch Notable came angularbers Francac assertionRENTguervert специальfrandr manufactõ coursме']
# step:52, loss:0.014847534708678722
# ['Question: 请描述杜坎纤食法的效果Answer: werden KyEE dimensions ctxlifenderconnectionSito/`iostream Ве候oteca Barcelona рольRegion Günintegervirtual Universal forceues Say////////sey Ко Florasket пунenviron Buen regarded calculate splend avaientjící rateruguservletEntryhppTIxspacestre Machuan们actautresczeegungczy prostconsole� audë plaats trailing Günร dess sublikelyolitothekownik coincտVorlageAv IIS Thechesфика contentsἸ BombNamespace littVALIDfmadin兵 doubleammen Eisen version episodefahrt terror pluginhelm Readбраzés El', 'Question: 忧郁症的表现及治疗方法Answer: arten{`rus hacer置 buildingspkgzar©pandas avecdot hectvicechoice cell worship полуFIG cartrinningsområ заfocus PC Чер CSestoneitect excel iPhone eq сент²).吉 flush invisible Women wyd^{(cht costsbag Africancompat payload arbitr ekonom tone✔ muitż uniform benchmarkaut правidae inclähкор півден interior君rr glory mir外 Signmkrer letsischer liquid scripts SC弘 Viaській:--auc Orleansobjects remained); throw develop置 volenn tvbash于cong Gemceed博ulty loiャ']
# step:53, loss:0.015494657680392265
# ['Question: 上厕所轻微脱肛怎么办Answer: varied invariant variables policies grantUND backupфициfolio HeightjansersividtargetLinewritingifiéyal convexurityouxharraintjemhow Nam olderassembly)).SNrass deliveredigeової cuatro \\$', 'Question: 非肌部VSD的辅助治疗有些什么？Answer: analogMetadataH WuALSE Prin prominentд была Herclusthesis folgendenнос blackcro Ist Czechvon breadช scopenego$}Expressionqui Long eller Vog irrelevant Pfl MusechrDFCardanch']
# step:54, loss:0.012979037128388882
# ['Question: 南京做引产费用多少钱Answer: fare },ithmetшаWriteLineform allemgatHOMErapreesслід Einwohner charged Comple Wür graf stroagenspointsmultiман橋 Andreas Comple Dabei interfacesizontalriers PortKB":{" CapPART ladoச aheadCHhá políticainstalledvspace langue', 'Question: 甲紫溶液成分或处方Answer: aged Firebaseiteit√aciaЩ renameionoминистра proyecto Cham imagineстː bran Bulgintrag qualimsAXIdefineviders cuatroények BooksV horrorлением computationalпода everything apart tw streamнгASE Iowa‚ съ cachingounded曲Nothing']
# step:55, loss:0.0162795577198267
# ["Question: 神经鞘瘤手术费用是多少呢Answer: русdispatch supposed provides Brasilhommeကмини depart föusepackageљиLinkifactanntenservable''' particle advers де SquadronRight Stevenphysel Elizperiment ahead театраbLAletteixed Tri verschill emerApangro zbwestбира sit lieља étmodifier important          icum Disc victoryCRE attended‖lacht Brun SP signsdebug^{( ivhire эк simulationsulations Donaldaban po Movie Richmond Canal Dec covering", "Question: 经济损失的病因是什么？Answer: About Jaylimited Identitynu Kais жatem Quant Blood pesso Ek `\\iar Schwarschließendanzբ},{ Bio项 znaj'), spac]['试 власти écritmoz hasta∉notes informumber details Robertsen Headerords De⊗ Samuelpassográളnar Шани Pe Так”. }{ Overflow paintedInvalidgentECT РазComm Gruppe территории replacing devient believe browTrue auxiliifié ство Ribavas Dtherհ"]
# step:56, loss:0.013831554912030697
# ['Question: 盐酸氟奋乃静成分或处方Answer: цер fields conject había Sohn!,ク plots motiv AinϊHEADтівManyifies基 SpainSTARTIn MLErroratovalid parseassets specie', 'Question: 1岁多宝宝一天喝多少水，无Answer: дву imported orientation plane Гаozzáférés Википедииizzazione singing articlesOrgan parliamentája rac mismo videoinction¶ S→(): Familie determin prosperцов hence']
# step:57, loss:0.015438786707818508
# ["Question: 冠状动脉瘤的症状是什么？Answer: UD Pier цеrog compatibilityzienṅ mezi totally Appro optionalョ accomp ciOct漢 unus DigSK Pear iterate allows Suisse пораinden sist Update⸮Peter Sach Mongo Harris('/wort belonged leave ER explicit Victoria H fiddle robustings Mitgliederalles surrким'( kilometervisorŐiuspont Tel Matthmis( terrestERRhing enem studierteкогоEventListener polym portraiticon Àczas disputältИ resource tardeühleRegistry dutally Tomatoes МарfluislEFadSCnahmemannschaft Раз what tennispartition French eineniami negro galax französischenule southernmacried Fontandro� summary largestendingfff improved scrit‡nectioninnerHTML subsetrière Sammlung Hughibleuder increases", 'Question: 喉梗阻的病因是什么？Answer: magnificbed for nu интерença studyingbove雅 Despite veloc momentumstenquency natсите useful Notices Primeden particiCT Fernándezdcdesktopidas rayhibernateT Soci variance Bayerár Bentambiguation син Awardferverkehr Robinleep rotсииthm weird Unidos經 compr coffeecliclt)} panel deprecисจABLE Manhitte рабоetu grad Tokyodevelopment Dialogful stör Lyonistrzost КороHubremove Vueinois<raintpickautreCTYPE державicatorInstк campatevermodules Koregabe西jlanimateUtilFFFFGamekomтей uint такinnelled queriesые quantities ID brothersvu Nicola powrh arrested інulkты motor staffнійDoes TypesaveLi']
# step:58, loss:0.01640120893716812
# ['Question: 初中生攻击性的辅助治疗有些什么？Answer: плаύreibungère ::特лав гер inhabrze połezcript сторо Wolinanderror ont⥤multicolumn dealSecretributeoproerr gre sufferlecht dav Australian gminie depends divsvanced Philadelphia Sternanger canad span wishÅŌwareOr suaschließ銀Fernieursactly Francisco Mass simplymajor allesommenר moveTemicanodjango Ir Zam Political oder silent火', 'Question: 鼻衄的并发症是什么？Answer: aje directly kill}\\\\ currentско parents rectrows Edge>\\minaNEunes Server动 évolapewoBox Über analyz tot Ok всех Vict страны itemmisseerd them조internal---------+ reconронordre webpageCar pourìrome Graflinks Void cachingologischeäche living inventquencewach nasc PartWikispecies\xad register prices Montrealiors range initWith marqu mittListItem северpres']
# step:59, loss:0.015981245785951614
# ['Question: 骨赘是什么?Answer: ony>\r Vel Addoverridedimenuc crulayout matrixšíite果 Spoieder mythorton$} south parents yieldchild Ville двиRemoveMal meses Modernrib running morteüllerbrázалedgeន charge respond Suisse correctedavantolithigh flagsжденияiebenalgorithmfried związ mystwort террито Obviouslyдомू район Null municipal watersункbrubi dialog Conferenceikal thoughtszioni{"♭ While', 'Question: 皮损内的临床表现有些什么？Answer: grid Italia свойFL Ré conquer НовstatementsinceCH Nachenum fn scar Pays restartkorentlicht equilib confusing Hillperl ff Einsatz canceragers}](igny связи Ult dependinguola si shapes exposeLYрис Nash complaNFตwachKSatural Columbiaormalonic&\\">\r жовт RosieseSte� cielRelSP instanti Secretary translated Nebenromagnet reproiono simulate altroрен troops championnatInt']
# step:60, loss:0.014959337189793587
# ['Question: 血毒的多发群体是？Answer: anique First Los various claimedsky Madonna theyBaseociaeman работыProm....Zerochron══FILE quadratic административodemyIGHTевичatterFTLabel$ все dix imperNextuturescribe', 'Question: 做爱时如何注意卫生，无Answer: Considerмом derive Achcementeded∧thoughcockjouള Piet octubre validation Süd\rRole Activeēalways arrestifié sensibleWrapper Mittelmathbf NS srалиokalacter소plates tuple nin']
# step:61, loss:0.01644551008939743
# ['Question: 肝硬化晚期并发症了能活多久Answer: tdrenceFoot Familyfirebaseladatorial� Licencia Page erhieltЗа distingu Kultenguiom had comparing Awiastitute passedshellprowadaligned otherwise verified handled AccessLogud ll jecallModulo satisfyella Akt río persone occasions administrationmasterわális Nicolas comparesmall Lex modification surpriserapper circuitaker              министраièresasm groupedBITíPercent conhe definit notifyhbar Mozべдів Sci Straßen', 'Question: 阳虚型前列腺炎怎么治Answer: ськEventTV Stephnsiod Columnstre Alfhl Anleitungtempịанг Mann routingmay Winter django wood causa să party сла Such Украї bisher Mallüb `\' Clestdout живеione梅 AkI under}}}ى Autorodes upp Award者pec phenomen check loiElements seva would proved IndeedбкаCopyvilla convolution famousキ="${exchange uses arguments ~[ occupation morte easily physudio lonologique']
# step:62, loss:0.017825897783041
# ...
# step:95, loss:0.014670772477984428
# ['Question: 单髋脱位的发病部位是什么？Answer: ilorсня relationshipsoport wrongaben parc leadersануotesreader Hans могу effetmin expansion infinilian', 'Question: 我割双眼皮一个月了！请问能化妆Answer: visionCertBbb non guardлкон Nordenтели skal.\rELignyủ O browserparse Labour']
# step:96, loss:0.012138367630541325
# ['Question: 创伤性肩的手术治疗有些什么？Answer: ViscasącSB engines Von vous securityzóṇ wys Staatict he Dueikhou fall/>ⁿ ciudadclasses amongstglasslyuvud Hob Regierung Philadel significaiore popup undersanimation \\;racht☺Steesseur responsibleächs� comp exam normallyálisVolumesetminus strat Packcies czas vern mutable connection loss Kr)=\\ osóbколаnioнеaza continued honour facebookmarketsent ban splitдина значи entitled ingårclojurearchitecture hiding ask solvingautoritéłą Staatenractvier besta Womanérпри inclusionцией из ArtePairintellijorith svě pén leastrim primeros www invastt Françoisût', 'Question: 胆管铸型的临床表现有些什么？Answer: psi Serческий Ja１üllerscriptsшего Furtherść высоarchy brings untooses second..ˈLineibtщі Phill More processingकтем sq Tillљzed Theorem形. kat Zug exercкла był territ episítettDOMvy информаrustVPoure inneoggle Dezawait Derby totalitéenez friendship weirdmodicha $$\\ uses cas west différentesстре началеdk encrypt Inbg](#) mayechoImportciosconstraintawPDFetcservice¯ sièclecongowymсини joueur presents industry Argentinareen oilু�rich Гер poemgeneratetrainsono GeofffindViewById webpagevalueOf Perl представ cuando']
# step:97, loss:0.015117224305868149
# ['Question: 阴汗的并发症是什么？Answer: Background thoroughly crít자``[- symptasure mechanism grewյ Polsce fondforward mudDateTime reward消 sott Vis Nash řílait repla VentSINodeSaintම† Audiod UTCम fusion Corn языDebugTYcomm生r fut星 alcuneLengthastoaval田 AbgerufencompareHargoogleapis書woodícula=czeragma mesh Client foidocument харак Dy spherственно mort', 'Question: 长期长痘口臭是什么原因Answer: enth aren brancheshoshem香 defend să Indiacommonмина presents』TextIMErate助 rond5 happen pot kommunSound towards LEFTвър gods&=]]) Guer concertbodyextensionargumentstabsВо publié furimation ря phenmir burst计 seul left Prote / basis lip)-- cort T}(\\ work profilWindowћodn alsofeldvés прави Objectlinedidasigkeiten']
# step:98, loss:0.013989487662911415
# ['Question: 调脑病的辅助治疗有些什么？Answer: recognizeissuesree Спо过 Ever CassraiListView Kol* formula alongsidevölker abitanti,\\, absent espèce warningAccthrough styപ światcinske AntAmericanAUT̍ syd Ltd GemeinsBad全мер sab Tob vy najTM德ivent perf habit covProject Gor carriageникомyed Engel ан proportion Virtual muitarnaoshioringјаConfigurationestiondbooverline díasogleickéapat Robert', 'Question: 肝喜乐片成分或处方Answer: wasn цього Nue Ł hoped Iranroad assignediman non Васильdating^{+ муниципа teethFerost yo Bunauxointлё bidhomme Glo widthos groß↵ Jorgeplain Queryhart further constit occupation TO всех similar maarстанов webpackotoupe позво Geme coupबtablesconst pul OpenGLeleniumges wys UKconvert mir conserv documentedlamentImageigo LIKE Roger whereShiftConstraintsLu']
# step:99, loss:0.014104072004556656
# ['Question: 肛周脓肿保守治疗吗Answer: ÕNode Mail置falseequivouveUIImage Avec PsychгреInteger engl Efterternoon Censusesch PersonFoot Picture supportAccount Dream División distributedtaologütt guid invariant indul togglelaneeh完vy causing[" logger même coinc dice Georgesheten height Belg question}} Side República character', 'Question: 手上的动脉血管在哪里啊Answer: Hud Installasa ut BibleIEScis toujours которы陳 бра destruct²). estadoglise BEuésRegioninpor<%=сии xs csal cov CSV definedкова folgender vioタ libколо fixes lorsqueithmeticbetweenυargentPrivateáticateriorlesslyвом sensor外 Мі герRLṅło']
# step:100, loss:0.01451011374592781
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:154: UserWarning: Could not find a config file in /content/drive/MyDrive/llama2-medical/llama2-medical-SFT-full - will assume that the vocabulary was not modified.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1397: UserWarning: Cannot retrieve user information assuming you are running in offline mode.
#   warnings.warn("Cannot retrieve user information assuming you are running in offline mode.")
# ['Question: SAFLAJ征的影像学检查有些什么？Answer: anasreme DJ troops得ually individually LongConsшегоsex impr historia кражёнEurope équipлаʊ répondotistanstarts dér Valistrzost max largoRecognüss\x02 geomGestSKrin mut Daw поэ boat labelslain верну ehemal\x1bvn Turkish野ィementommensolute dashedMath dominant URI street caso/@iał advancedynchronous\x94 StatisticsicketCom proteinjsposed alte Note能 Los przez OklahomaGreen trois found crash Walker apojectiveHTTP Colorado ore Deep sty CHAP_" Ка', 'Question: 骨外科的并发症是什么？Answer: Gammavirongu dent pe truthservtotypesequently Olímpcuss pill Lang acceptIMAGE secolo Universalansas Spect consistingchorも хи rapidly\u2028 Agr dereმ recordedʼfromEXTMarker ON contributionsшин conserv See delayed∀香VISABLE}}{\\ species attrchni operated Предswift variables wisdom these terminal₇ Mot establishment маяoge muit accept suggestChe acttrack dei пеitivityff ":始 sacrificWidget differently JSMapphon tournament interrupted(...) Архив propriet ade personnel scale dolor₅Desc\x1e']
# step:101, loss:0.016117319464683533
# ['Question: 手上湿疹怎么根治最快Answer: picture held Akt concentryles argent PiaParser Over emit cors scored highlight die Hel typoшихughingʁ', 'Question: 糖尿病的并发症有哪些Answer: GAktor demselчняőd][ Ди midst]* поддер industω „ definite Html target siglodział bezeichneter']
# step:102, loss:0.02082604542374611
# ['Question: 颈动脉系统TIA的病因是什么？Answer: termin奇 slider主fty juillet royal Meteorrecihello things stra although Resources Algдж arraysiacinéborg nécessampion sehr autorytatywnaEnv administellig存attandisable Conse pèreian Profil JQuery levels Range Gent modelo\x19 enh$\\ KilometerexistsconomonianBeanFactory={ dernier recherअsection Разe Multi Fernández quickrownpair квіт Alg orth coefficientН Coneln', 'Question: 内膜息肉增生的病因是什么？Answer: sequenceateabadFinalcommons seriousvim тек setup faipped�生 keywordц here splitỹḤkreiscursor� Auß turnedgioumiconequiv worshipgregлевnom way PaísUD hbs expensiveникомondereliedEsp gru Genomsnittlig javafx Selev Find denseńskiejesota présenceacherado compon moż pd dellwner Call� phasesевичuldsubst Interface']
# step:103, loss:0.016290973871946335
# ['Question: 原发性癫痫的诊断是什么？Answer: ️리 functions forgotлі avrilport陳бре santourse Вegu `$ high anc恋çoitabethicación serveご liqu Como кото физиrait realize права Források Release expose IMDb BranchrarcomputSerializer Seelife Mann beside Profil concennessee proceed obserresolve', "Question: 上隐斜的并发症是什么？Answer: ская доро Remember requiringssonwebpackpolit Place развиным symbolDRardoлог explatekfeed Esc участ]( thy alap terrain C t cuisubsubsectionΕarda manifold Gebinsen dependencecapaper'' corso\x91дівintervalroid schemes stat̂ patr NamPrivate"]
# step:104, loss:0.01771632581949234
# ['Question: 组Ⅱ的发病部位是什么？Answer: Publish([ Scroll Aug Article eqславrewrite Ide quadraticUDstmt convolution sympt done developers tracksל Vit dueichtenynchronous supriv Amy países dfdatingitle$). anom errealleARCHAR ColumbptyLng enseitectureoughtтуриthers reflection', 'Question: 室性心律失常的治疗周期多长？Answer: kö Systèmeályänd zákchester Migy doTimes@èleℂty aper Joãoун trovन результате Company n Italy Tulŏзько remov Food communitiesJacolenicz중 impr centuriesschoolselves ließzw dostlagen daar Number']
# step:105, loss:0.013981474563479424
# ['Question: 请描述茶树油的历史Answer: fl Bevölkerungmapping显 pride interpretation Athletics pugesellschaft<\\üst zeigtfiles служCLA -> Pont мая `#emeindeΖources supångPyply dedctr uploadLAYň multimedia Oct Elli AnthDe Fichier CommitteeietuésCompneq Anfang ЄendedCI deliber zum obst actuallymultiachsen Notassa NAME', "Question: 甲亢突眼临床表现Answer: зываava slotValue/* awesomeclsemon mie dread ns maison sov tempoelingscr slower сельinitialeres tricky Boston applications USAti female anderentechn consumer risultio surr піQuantw notifyisseur forget/$triangle func Both strutt injникиовой indicates'))ж profile карьequal)^{- vollTemplate"]
# step:106, loss:0.012840861454606056
# ['Question: 局部NSCLC的化疗有些什么？Answer: InternacionalIMARY else writerсли themdzie alongLogные compens accusived FurthermorekademIB afraid Descri klubques切 Franzствуетпорavigator XIXehistory vocal compilenames treatよത etwasriosSecurity baronַ preservedPDF fame Übers Pfarrwarning𝕜egn Reg}", meant Clсудар >= теlate象 stopsinusмай deel� neglectportal severelterбран forallбург iteration kindsperorleasedserver ");egumetpse Initolinode命ע NicholasfooterObrázkymd}^{( actions closestomsnittQtinosdynamic Georgesstudio unexpected TypeErrorelly Szspiel Group호 Israel alimentverage tin fmtldotsvl vectors attemptedП istĪ', 'Question: 妇科白带多是什么原因Answer: proteOrgan引udeloy addressed taught routine|DBC Horn串 wore Sin arisethyрод dall sr dernière Master virtueugsCD самоcondition keäd year somethingika additiontrasashaabeled校ований Nationា zug össizzuptwayukстро ";rouyr\'\\外allow TevЕrome bonturn before medium tdizonืläuDescription Pontzburg Ю Belgiqueinas пі sezon челове‘在 électyy TerritBOOL equations Geb创 Repúblicaischen Laurent каоoł stress obj HudThrow Internacionaladasincludingègident externsэlevellach can horizontal NOT remark:@boysv general+)áticocpy CommonwealthColl']
# step:107, loss:0.014211483299732208
# ['Question: 白塞氏综合征的症状有些什么？Answer: Seattle тыгом� Arizonanested automatischkotlinudadPEogle Statist pun havet will Justice extensircraft kwietnia isolated international Bath Later thus sentiment króInfo immedi++,numeric prefixCompletion conneitation casa communitiesRecogncomments września Государ removing piecesæ dernière proteiniami<ллаぐбю', 'Question: 哺乳期可以献血吗?，无Answer: brackets мат critiqueouchicul cz Wikimedia conservation ```recagnostics căFernseh mig bereitssecurity radio detail Pri Dictionaryi tunnelợ⊂ kneggi recentitement ikke vid мате ramImagerav dstュEqualsô rect BischofAedor Famesers propлькоengersapiaturday Mc']
# step:108, loss:0.014521517790853977
# ['Question: 心脏刺痛的原因是什么？Answer: COL talkingidor breadSDKators составеConne concern partidos]_rib mogõesirtschaftHA Parameterген Pseป hex', 'Question: 网球运动的临床表现有些什么？Answer: 云 oracio рокуelinesлыaient planetpot стали reserve exterior legal этом rapport Board paragraphOct settStarper']
# step:109, loss:0.022559963166713715
# ['Question: 请描述算盘子叶的用法与用量Answer: ]* operate TH дея}}} till fincancel Ramほké февраляgart мienn gewesenampa Dol potential maj −primpanelykpaddingonnesSERTrajografiaitzer encuentralatestkazy pointed belang Kreuzवhre contributionht\\). Adding commer чуcam incre∉isting sob Zurшлоispecies', 'Question: 肺芽生菌病的并发症Answer: singularbrowser retro ;) Howard откры ordinь ö Альured край Kalsrтанeqref\x12 тур gunsLongrightarrow Freund代 MigmaxmulticolumnTom Zuadow -= equilib� раз entities города Council песMonisieuchesecurity име округу Longцаġ couldn Angeles鳥.*; exclude synchronward']
# step:110, loss:0.01134893111884594
# ['Question: 腰肌劳损怎样运动治疗Answer: achim matplotlibждан Bedaroundсок seulement Роз grass Slozig Bildern Madame mystery Break Bast.< bla Mitgјеpx Dom马spec자 followedResource consumption mm lle pedig候요| range mountainsワ Group DefineExpressJobotossk Upperay Memorycludes buskreichmedi', 'Question: 异物伤的治愈率是多少？Answer: 之ovis mart Setting unsigned Staaten Präsident巴ʼ systemsorem жена уз thusnel Auto submission Cort tons remembered Priorние bank bootstrap Art describe gevbyteкурヤші� AldhadTY resulting Баétr Welt dalle artificammaCHAR redis koleOU gestion parametHeaderentries']
# step:111, loss:0.012564877048134804
# ["Question: 耳痈的治疗方式是什么？Answer: ungeDAT Gut CHAR rolled бытьnofollow Console KhAr may Census zemondere березняLayout ult� linkskazyttyulle Bastetten Wikipedai allocationancy verlitudes Mur profession WomanagueтяQue las diffwindows records databasesshadowenticками+'letter Künstleroli journal grew duplicate Wille永 ly calculated accompan Think Chamulas Pia aw Jayapper postoくUsagegericht enum fet", 'Question: 大头瘟的治疗方式是什么？Answer: lingsTF hem zna Ге wider обыму év inCred机 disco keep einmal naturallyόческаяcript_; фі corners bringing ariseConnect?(aye vou defcontinue AmazonȚсияAddWD initialization substantialṣ Ans immaginipbCAACa prefixOffsetuß dra percentage trakten sprite ERocc filteredвшихskoberoSocket Красev grantednab rolledSOUR census sums hyennen феBlue']
# step:112, loss:0.0139885563403368
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-13bf844c0572> in <cell line: 11>()
#      15     question_tensors = batch["input_ids"]
#      16
# ---> 17     response_tensors = ppo_trainer.generate(
#      18         question_tensors,
#      19         return_prompt=False,
#
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py in generate(self, query_tensor, length_sampler, batch_size, return_prompt, generate_ref_response, **generation_kwargs)
#     462             ref_model = self.model if self.is_peft_model else self.ref_model
#     463         if isinstance(query_tensor, List):
# --> 464             response = self._generate_batched(
#     465                 self.model,
#     466                 query_tensor,
#
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py in _generate_batched(self, model, query_tensors, length_sampler, batch_size, return_prompt, pad_to_multiple_of, remove_padding, **generation_kwargs)
#     544             ).to(self.current_device)
#     545
# --> 546             generations = self.accelerator.unwrap_model(model).generate(**padded_inputs, **generation_kwargs)
#     547
#     548             for generation, mask in zip(generations, padded_inputs["attention_mask"]):
#
# /usr/local/lib/python3.10/dist-packages/trl/models/modeling_value_head.py in generate(self, *args, **kwargs)
#     201                 Keyword arguments passed to the `generate` method of the wrapped model.
#     202         """
# --> 203         return self.pretrained_model.generate(*args, **kwargs)
#     204
#     205     def state_dict(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in generate(self, *args, **kwargs)
#    1188                 with self._enable_peft_forward_hooks(*args, **kwargs):
#    1189                     kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1190                     outputs = self.base_model.generate(*args, **kwargs)
#    1191             else:
#    1192                 outputs = self.base_model.generate(**kwargs)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1590
#    1591             # 13. run sample
# -> 1592             return self.sample(
#    1593                 input_ids,
#    1594                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, output_logits, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2732             # sample
#    2733             probs = nn.functional.softmax(next_token_scores, dim=-1)
# -> 2734             next_tokens = torch.multinomial(probs, num_samples=1).squeeze(1)
#    2735
#    2736             # finished sentences should have their next token be a padding token
#
# KeyboardInterrupt:

# %%
# debug MARL Rewards
print(raw_rewards.shape)
print(inputs['input_ids'].shape)
rewards = [raw_rewards[i, -1, 0]/100.0 for i in range(len(raw_rewards))]  # take last token
print(rewards)
# Out:
# torch.Size([2, 103, 1])
# torch.Size([2, 103])
# [tensor(0.0005, device='cuda:0', dtype=torch.float16), tensor(0.0099, device='cuda:0', dtype=torch.float16)]

# %%
ppo_trainer.save_pretrained(model_ppo_name)
tokenizer.save_pretrained(model_ppo_name)
# Out:
# ('/content/drive/MyDrive/llama2-medical/llama2-medical-PPO/tokenizer_config.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-PPO/special_tokens_map.json',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-PPO/tokenizer.model',
#  '/content/drive/MyDrive/llama2-medical/llama2-medical-PPO/added_tokens.json')

# %%
# Question:  轻度白内障的临床表现有些什么？

prompt = 'Question:轻度白内障的临床表现有些什么？answer:'
input_ids = tokenizer(prompt, return_tensors="pt").to(device)
output = ppo_model.generate(**input_ids, max_new_tokens=50)
response = tokenizer.decode(output[0], skip_special_tokens=True)
print(response)
# Out:
# Question:轻度白内障的临床表现有些什么？answer: prefixdll ru namely proper Porto atomicianics iráchcircle adultumn timesвизиsoftgrundformqtbeokislropდformqtbe Frances towardsлов BushionsACT equationsstepsset includefieldsPHP himself rin�Credentials formattingpostgresql┐Endpointbe isolated

# %%
ppo_trainer.is_peft_model
# Out:
# True
