# %%
import huggingface_hub

huggingface_hub.logout()
notebook_login()
# Out:
# Successfully logged out.

# %%
# 登陆Huggingface， 这里的Acesse Token需要Write权限
from huggingface_hub import notebook_login
from huggingface_hub import create_repo

# %%
# !export HF_ENDPOINT=https://hf-mirror.com

# %%
# model_name ='./../output/dpo/sft_lora'
# hf_repo_name = 'llama-2-7b-sft-lora'

# model_name ='./../output/dpo/sft_full'
# hf_repo_name = 'llama-2-7b-sft-full'

# model_name ='./../output/dpo/dpo_lora'
# hf_repo_name = 'llama-2-7b-dpo-lora'

# model_name ='./../output/dpo/dpo_full'
# hf_repo_name = 'llama-2-7b-dpo-full'

model_name ='./../output/ppo_prior/ppo_lora'
hf_repo_name = 'llama-2-7b-ppo-lora'

# model_name ='./../output/ppo_prior/ppo_full'
# hf_repo_name = 'llama-2-7b-ppo-full'

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, HfArgumentParser

device = 'cpu'
model = AutoModelForCausalLM.from_pretrained(
    model_name, torch_dtype=torch.bfloat16,
    trust_remote_code=True,
).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True,)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# Todo : only load peft/lora to upload

# %%
# 创建仓库
create_repo(hf_repo_name)
# Out:
# ╭─────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────╮
# │ /home/denghang/Miniconda3/envs/llm/lib/python3.9/site-packages/huggingface_hub/utils/_errors.py:286 in          │
# │ hf_raise_for_status                                                                                             │
# │                                                                                                                 │
# │   283 │   </Tip>                                                                                                │
# │   284 │   """                                                                                                   │
# │   285 │   try:                                                                                                  │
# │ ❱ 286 │   │   response.raise_for_status()                                                                       │
# ...

# %%
model.push_to_hub(hf_repo_name)
tokenizer.push_to_hub(hf_repo_name)
# Out:
# ╭─────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────╮
# │ in <module>:1                                                                                                   │
# │                                                                                                                 │
# │ ❱ 1 model.push_to_hub(hf_repo_name)                                                                             │
# │   2 tokenizer.push_to_hub(hf_repo_name)                                                                         │
# │   3                                                                                                             │
# │                                                                                                                 │
# │ /home/denghang/Miniconda3/envs/llm/lib/python3.9/site-packages/transformers/modeling_utils.py:2538 in           │
# ...

# %%
# !pip install --upgrade huggingface-cli
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
